# %%
import pandas as pd
import numpy as np
import timeit #imports timeit module
from sklearn import preprocessing
from sklearn.model_selection import KFold, LeaveOneOut,cross_val_score, train_test_split
from sklearn.metrics import confusion_matrix, classification_report,f1_score,accuracy_score,precision_score,recall_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import neighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

def standardize(x): 
    
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x)
    df1 = pd.DataFrame(x_scaled)
    return(df1)

def ML_summary(Vars, model = None):
    
    #define X and y variables
    X = df.loc[:, Vars] 
    y = df.loc[:, "positive_negative"] 

    #standardize data
    X = standardize(X)

    #set the model
    if model == None:
        raise Exception("Needs Model")

    #set the CV
    kf = LeaveOneOut()
    
    #start timer for getting elapsed time
    from time import time
    import timeit #imports timeit module
    start_time = timeit.default_timer() #defines start time so computational time can be calculated

    #define lists
    acc_score = [];
    Truth = [];
    Output = [];

    #loop though each fold (so 40 times in our case)
    for train_index , test_index in kf.split(df):
        
        #split the data
        X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = .25, shuffle=True)

        #print(X_train); print(X_test); print(y_train); print(y_test)
        
        #fit the model
        model.fit(X_train,y_train)
        
        #preduct values
        pred_values = model.predict(X_test)

        #append the accuracy score
        acc = accuracy_score(pred_values, y_test)
        acc_score.append(acc)

        #add to the truth and output
        Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
        Output.extend(pred_values); ## it is a list  
        

 
    #determine the time elapesed
    elapsed = timeit.default_timer() - start_time #gives total computation time

    #return the dataframe
    #test = pd.DataFrame(data={"Predicted:": Output, "Real": Truth})
    
    #set output to a dataframe
    dfOutput = pd.DataFrame(data={"Model": str(model),
                                  "X Variable(s)": [str(Vars),],
                                  "Avg Accuracy": [np.mean(acc_score),],
                                  "SD of Accuracy": [np.std(acc_score),],
                                  "Sensitivity": [recall_score(Truth,Output,pos_label="negative"),],
                                  "Precision": [precision_score(Truth,Output,pos_label="negative"),],
                                  "F1-Score": [f1_score(Truth,Output,pos_label="negative"),],
                                  "Runtime": [elapsed,],
                                  "Confusion_Matrix": str(confusion_matrix(Truth,Output))}) #,"Real Specificity": [1,]
    #return output
    #test = pd.DataFrame(data={"Predicted:": Output, "Real": Truth})
    
    return dfOutput


def ML_compare_variables(modelList,variableList):
    
    outputList = []
    
    for j in modelList:
        
        outputList1 = []
        
        for i in variableList :
            outputList1.append(ML_summary(i,j))
            
        outputList1 = pd.concat(outputList1, ignore_index = True)
        
        outputList.append(outputList1)
    
    outputList = pd.concat(outputList, ignore_index = True)
    
    
    return outputList.sort_values(by = "F1-Score",ascending=False)

# %%
df = pd.read_csv('Cataract Data 1.3.csv', na_values='?').dropna()
pd.set_option('display.max_rows', None)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["ogAA_letterCode"] = le.fit_transform(df.ogAA_letter)
df["mutAA_letterCode"] = le.fit_transform(df.mutAA_letter)
df["ogAA_charCode"] = le.fit_transform(df.ogAA_char)
df["mutAA_charCode"] = le.fit_transform(df.mutAA_char)

# %%
#summery of all vars
ML_summary(["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"],RandomForestClassifier(max_depth=3))

#Compare all variables
ML_compare_variables([LogisticRegression(solver= 'liblinear', class_weight = 'balanced'),
                      neighbors.KNeighborsClassifier(n_neighbors = 3),
                      LinearDiscriminantAnalysis(),
                      DecisionTreeClassifier(max_depth=3),
                      BaggingClassifier(),
                      RandomForestClassifier(max_depth = 3),
                      AdaBoostClassifier(n_estimators=500, learning_rate = 0.1, algorithm="SAMME.R"),
                      GradientBoostingClassifier(n_estimators = 500, learning_rate = 0.1, max_depth = 4),
                      SVC(C=1, kernel='linear')],
                           [["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"]])
# Out:
#                                                Model  \
# 5                RandomForestClassifier(max_depth=3)
# 3                DecisionTreeClassifier(max_depth=3)
# 6  AdaBoostClassifier(learning_rate=0.1, n_estima...
# 4                                BaggingClassifier()
# 7  GradientBoostingClassifier(max_depth=4, n_esti...
# 1                KNeighborsClassifier(n_neighbors=3)
# 8                          SVC(C=1, kernel='linear')
# 2                       LinearDiscriminantAnalysis()
# 0  LogisticRegression(class_weight='balanced', so...
#
#                                        X Variable(s)  Avg Accuracy  \
# 5  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.9100
# 3  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8800
# 6  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8775
# 4  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8750
# 7  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8500
# 1  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8175
# 8  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8175
# 2  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.7725
# 0  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.7425
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score    Runtime  \
# 5        0.073485     0.974790   0.885496  0.928000   6.997925
# 3        0.087178     0.901460   0.921642  0.911439   0.160103
# 6        0.110651     0.912214   0.901887  0.907021  35.043510
# 4        0.096825     0.917323   0.889313  0.903101   0.993370
# 7        0.097468     0.900383   0.873606  0.886792   9.538576
# 1        0.118084     0.984674   0.788344  0.875639   0.235147
# 8        0.133954     0.976654   0.789308  0.873043   0.197954
# 2        0.109516     0.862903   0.789668  0.824663   0.284243
# 0        0.132075     0.734615   0.848889  0.787629   0.213992
#
#           Confusion_Matrix
# 5  [[232   6]\n [ 30 132]]
# 3  [[247  27]\n [ 21 105]]
# 6  [[239  23]\n [ 26 112]]
# 4  [[233  21]\n [ 29 117]]
# 7  [[235  26]\n [ 34 105]]
# 1  [[257   4]\n [ 69  70]]
# 8  [[251   6]\n [ 67  76]]
# 2  [[214  34]\n [ 57  95]]
# 0  [[191  69]\n [ 34 106]]

# %% [markdown]
# # Logistic Regression:
#
# Coming out of the Exploratory Data Analysis, we knew that more linear classification models like logistic regression would not be the best fit for our data primarily due to the nonlinearity of variables like the isoelectric point. We tested it nonetheless and found our mini hypothesis to be true. After testing 15 different relevant double combinations of variables, like the isoelectric point and evolutionary age as pdel variables, we found that the best average accuracy rate of the logistic regression model was around 72.75% when it considered the variables pdel and $\Delta$$\Delta$G3 (the $\Delta$$\Delta$G values found by the INPS3D bioinformatics tool. It had a sensitivity of 0.70, precision of 0.87, and F1 score of approximately 0.78.

# %% [markdown]
# ### duos

# %%
ML_compare_variables([LogisticRegression(solver= 'liblinear', class_weight = 'balanced')],[["iso_point", "pdel"],
                                                     ["iso_point", "solv_area"],
                                                     ["iso_point", "deldel_G1"],
                                                     ["iso_point", "deldel_G2"],
                                                     ["iso_point", "deldel_G3"],
                                                     ["iso_point", "ogAA_letterCode"],
                                                     ["pdel", "ogAA_letterCode"],
                                                     ["solv_area", "ogAA_letterCode"],
                                                     ["deldel_G3", "ogAA_letterCode"],
                                                     ["deldel_G2", "ogAA_letterCode"],
                                                     ["deldel_G1", "ogAA_letterCode"],
                                                     ["pdel", "deldel_G1"],
                                                     ["pdel", "deldel_G2"],
                                                     ["pdel", "deldel_G3"],
                                                     ["pdel", "solv_area"]])
# Out:
#                                                 Model  \
# 13  LogisticRegression(class_weight='balanced', so...
# 0   LogisticRegression(class_weight='balanced', so...
# 11  LogisticRegression(class_weight='balanced', so...
# 4   LogisticRegression(class_weight='balanced', so...
# 6   LogisticRegression(class_weight='balanced', so...
# 8   LogisticRegression(class_weight='balanced', so...
# 12  LogisticRegression(class_weight='balanced', so...
# 5   LogisticRegression(class_weight='balanced', so...
# 14  LogisticRegression(class_weight='balanced', so...
# 1   LogisticRegression(class_weight='balanced', so...
# 7   LogisticRegression(class_weight='balanced', so...
# 3   LogisticRegression(class_weight='balanced', so...
# 2   LogisticRegression(class_weight='balanced', so...
# 9   LogisticRegression(class_weight='balanced', so...
# 10  LogisticRegression(class_weight='balanced', so...
#
#                        X Variable(s)  Avg Accuracy  SD of Accuracy  \
# 13             ['pdel', 'deldel_G3']        0.7275        0.104851
# 0              ['iso_point', 'pdel']        0.7200        0.120830
# 11             ['pdel', 'deldel_G1']        0.7125        0.116592
# 4         ['iso_point', 'deldel_G3']        0.5750        0.197167
# 6        ['pdel', 'ogAA_letterCode']        0.6550        0.162711
# 8   ['deldel_G3', 'ogAA_letterCode']        0.5600        0.117898
# 12             ['pdel', 'deldel_G2']        0.6550        0.149917
# 5   ['iso_point', 'ogAA_letterCode']        0.5575        0.192208
# 14             ['pdel', 'solv_area']        0.6400        0.157797
# 1         ['iso_point', 'solv_area']        0.5250        0.189407
# 7   ['solv_area', 'ogAA_letterCode']        0.5075        0.121218
# 3         ['iso_point', 'deldel_G2']        0.5000        0.212132
# 2         ['iso_point', 'deldel_G1']        0.4775        0.221909
# 9   ['deldel_G2', 'ogAA_letterCode']        0.4400        0.139284
# 10  ['deldel_G1', 'ogAA_letterCode']        0.4425        0.124273
#
#     Sensitivity  Precision  F1-Score   Runtime         Confusion_Matrix
# 13     0.703297   0.872727  0.778905  0.111096  [[192  81]\n [ 28  99]]
# 0      0.671937   0.854271  0.752212  0.128899  [[170  83]\n [ 29 118]]
# 11     0.665306   0.831633  0.739229  0.102095  [[163  82]\n [ 33 122]]
# 4      0.739777   0.665552  0.700704  0.111867  [[199  70]\n [100  31]]
# 6      0.555556   0.892857  0.684932  0.104066  [[150 120]\n [ 18 112]]
# 8      0.671480   0.686347  0.678832  0.143116  [[186  91]\n [ 85  38]]
# 12     0.543726   0.888199  0.674528  0.108414  [[143 120]\n [ 18 119]]
# 5      0.709302   0.642105  0.674033  0.104357  [[183  75]\n [102  40]]
# 14     0.498069   0.902098  0.641791  0.124133  [[129 130]\n [ 14 127]]
# 1      0.596899   0.641667  0.618474  0.123548  [[154 104]\n [ 86  56]]
# 7      0.588015   0.643443  0.614481  0.128175  [[157 110]\n [ 87  46]]
# 3      0.616601   0.602317  0.609375  0.142122  [[156  97]\n [103  44]]
# 2      0.526923   0.614350  0.567288  0.135921  [[137 123]\n [ 86  54]]
# 9      0.531365   0.597510  0.562500  0.130144  [[144 127]\n [ 97  32]]
# 10     0.526515   0.586498  0.554890  0.120006  [[139 125]\n [ 98  38]]

# %% [markdown]
# ### duos and trios
# We tried out logistic regression models using not only combinations of two covariates but also combinations of three. But even taking those into consideration, _____.

# %%
ML_compare_variables([LogisticRegression(solver= 'liblinear', class_weight = 'balanced')],[["iso_point", "pdel"],
                                                     ["iso_point", "solv_area"],
                                                     ["iso_point", "deldel_G1"],
                                                     ["iso_point", "deldel_G2"],
                                                     ["iso_point", "deldel_G3"],
                                                     ["iso_point", "ogAA_letterCode"],
                                                     ["pdel", "ogAA_letterCode"],
                                                     ["solv_area", "ogAA_letterCode"],
                                                     ["deldel_G3", "ogAA_letterCode"],
                                                     ["deldel_G2", "ogAA_letterCode"],
                                                     ["deldel_G1", "ogAA_letterCode"],
                                                     ["pdel", "deldel_G1"],
                                                     ["pdel", "deldel_G2"],
                                                     ["pdel", "deldel_G3"],
                                                     ["pdel", "solv_area"],
                                                     ["pdel", "iso_point"],
                                                     ["solv_area", "deldel_G1"],
                                                     ["solv_area", "deldel_G2"],
                                                     ["solv_area", "deldel_G3"],
                                                     ["solv_area", "pdel"],
                                                     ["solv_area", "iso_point"],
                                                     ["pdel", "iso_point", "deldel_G3"],
                                                     ["pdel", "iso_point", "solv_area"],
                                                     ["pdel", "iso_point", "ogAA_letterCode"],
                                                     ["pdel", "iso_point", "deldel_G1"],
                                                     ["pdel", "iso_point", "deldel_G2"]])
# Out:
#                                                 Model  \
# 21  LogisticRegression(class_weight='balanced', so...
# 13  LogisticRegression(class_weight='balanced', so...
# 24  LogisticRegression(class_weight='balanced', so...
# 15  LogisticRegression(class_weight='balanced', so...
# 0   LogisticRegression(class_weight='balanced', so...
# 4   LogisticRegression(class_weight='balanced', so...
# 25  LogisticRegression(class_weight='balanced', so...
# 23  LogisticRegression(class_weight='balanced', so...
# 22  LogisticRegression(class_weight='balanced', so...
# 11  LogisticRegression(class_weight='balanced', so...
# 12  LogisticRegression(class_weight='balanced', so...
# 1   LogisticRegression(class_weight='balanced', so...
# 5   LogisticRegression(class_weight='balanced', so...
# 8   LogisticRegression(class_weight='balanced', so...
# 6   LogisticRegression(class_weight='balanced', so...
# 20  LogisticRegression(class_weight='balanced', so...
# 18  LogisticRegression(class_weight='balanced', so...
# 9   LogisticRegression(class_weight='balanced', so...
# 14  LogisticRegression(class_weight='balanced', so...
# 19  LogisticRegression(class_weight='balanced', so...
# 7   LogisticRegression(class_weight='balanced', so...
# 2   LogisticRegression(class_weight='balanced', so...
# 3   LogisticRegression(class_weight='balanced', so...
# 10  LogisticRegression(class_weight='balanced', so...
# 17  LogisticRegression(class_weight='balanced', so...
# 16  LogisticRegression(class_weight='balanced', so...
#
#                                X Variable(s)  Avg Accuracy  SD of Accuracy  \
# 21        ['pdel', 'iso_point', 'deldel_G3']        0.7775        0.133206
# 13                     ['pdel', 'deldel_G3']        0.7500        0.111803
# 24        ['pdel', 'iso_point', 'deldel_G1']        0.6975        0.125474
# 15                     ['pdel', 'iso_point']        0.6800        0.141774
# 0                      ['iso_point', 'pdel']        0.6825        0.164146
# 4                 ['iso_point', 'deldel_G3']        0.5925        0.211409
# 25        ['pdel', 'iso_point', 'deldel_G2']        0.6700        0.141774
# 23  ['pdel', 'iso_point', 'ogAA_letterCode']        0.6950        0.134071
# 22        ['pdel', 'iso_point', 'solv_area']        0.6450        0.148240
# 11                     ['pdel', 'deldel_G1']        0.6650        0.162096
# 12                     ['pdel', 'deldel_G2']        0.6550        0.120312
# 1                 ['iso_point', 'solv_area']        0.5800        0.184662
# 5           ['iso_point', 'ogAA_letterCode']        0.5575        0.161071
# 8           ['deldel_G3', 'ogAA_letterCode']        0.5400        0.128062
# 6                ['pdel', 'ogAA_letterCode']        0.6725        0.134141
# 20                ['solv_area', 'iso_point']        0.5425        0.175908
# 18                ['solv_area', 'deldel_G3']        0.5200        0.145258
# 9           ['deldel_G2', 'ogAA_letterCode']        0.4625        0.157619
# 14                     ['pdel', 'solv_area']        0.5850        0.140624
# 19                     ['solv_area', 'pdel']        0.5950        0.158035
# 7           ['solv_area', 'ogAA_letterCode']        0.4725        0.128428
# 2                 ['iso_point', 'deldel_G1']        0.4650        0.205609
# 3                 ['iso_point', 'deldel_G2']        0.4525        0.233439
# 10          ['deldel_G1', 'ogAA_letterCode']        0.4525        0.146607
# 17                ['solv_area', 'deldel_G2']        0.4625        0.160760
# 16                ['solv_area', 'deldel_G1']        0.4700        0.155242
#
#     Sensitivity  Precision  F1-Score   Runtime         Confusion_Matrix
# 21     0.775100   0.853982  0.812632  0.226672  [[193  56]\n [ 33 118]]
# 13     0.738776   0.834101  0.783550  0.262072  [[181  64]\n [ 36 119]]
# 24     0.654762   0.829146  0.731707  0.223842  [[165  87]\n [ 34 114]]
# 15     0.666667   0.809302  0.731092  0.210712  [[174  87]\n [ 41  98]]
# 0      0.632959   0.853535  0.726882  0.226691  [[169  98]\n [ 29 104]]
# 4      0.790262   0.663522  0.721368  0.275878  [[211  56]\n [107  26]]
# 25     0.647510   0.808612  0.719149  0.210248  [[169  92]\n [ 40  99]]
# 23     0.581749   0.927273  0.714953  0.242839  [[153 110]\n [ 12 125]]
# 22     0.575188   0.840659  0.683036  0.242959  [[153 113]\n [ 29 105]]
# 11     0.553846   0.888889  0.682464  0.239605  [[144 116]\n [ 18 122]]
# 12     0.573643   0.840909  0.682028  0.231157  [[148 110]\n [ 28 114]]
# 1      0.649635   0.712000  0.679389  0.228663  [[178  96]\n [ 72  54]]
# 5      0.706107   0.649123  0.676417  0.252178  [[185  77]\n [100  38]]
# 8      0.665399   0.645756  0.655431  0.240803  [[175  88]\n [ 96  41]]
# 6      0.514768   0.884058  0.650667  0.239013  [[122 115]\n [ 16 147]]
# 20     0.619231   0.657143  0.637624  0.216608  [[161  99]\n [ 84  56]]
# 18     0.572519   0.652174  0.609756  0.231793  [[150 112]\n [ 80  58]]
# 9      0.583969   0.590734  0.587332  0.234686  [[153 109]\n [106  32]]
# 14     0.448276   0.841727  0.585000  0.240694  [[117 144]\n [ 22 117]]
# 19     0.441860   0.863636  0.584615  0.218871  [[114 144]\n [ 18 124]]
# 7      0.546816   0.618644  0.580517  0.236362  [[146 121]\n [ 90  43]]
# 2      0.523077   0.601770  0.559671  0.198796  [[136 124]\n [ 90  50]]
# 3      0.553785   0.565041  0.559356  0.202714  [[139 112]\n [107  42]]
# 10     0.543307   0.572614  0.557576  0.196783  [[138 116]\n [103  43]]
# 17     0.483395   0.635922  0.549266  0.250979  [[131 140]\n [ 75  54]]
# 16     0.447761   0.652174  0.530973  0.213727  [[120 148]\n [ 64  68]]

# %% [markdown]
# # KNN:
# Prior to training models, we knew that KNN, or K-nearest neighbor, models would fit our data better (primarily due to its friendliness to nonlinearity). The figures prove as such; 13 of 21 combinations of covariates provided a model with an average accuracy higher than 90%. The model with the dual combination of isoelectric point and pdel as covariates showed, on average and most consistently, the highest accuracy and F1 score of approximately 95% and 0.96, respectively. The sensitivity was 1.0 and the precision was 0.93. From the KNN models, we found that our mini hypothesis from our Exploratory Data Analysis was correct. Isoelectric point was consistently a covariate of each combination of covariates that provided the models with the highest accuracy, showing that it was a variable with high predictive power. When we compared the "top" lists for each leading covariate (ie. isoelectric point and one of either pdel, solvent area, the $\Delta$$\Delta$G's, or the original amino acid letter codified with a numerical variable), the models with isoelectric point as a covariate consistently had the highest average accuracies. The models with pdel as a covariate had the second highest average accuracies, with the $\Delta$$\Delta$G's trailing behind. It was testing the KNN models where we realized that the highest accuracy may hover around 95%; there are two outlier data points for isoelectric values between positive and negative groups. The reason for why they are outliers are likely to be found with further biological and biotechnological research. No matter the combination of numerical covariates, the accuracy hovered around 0.95 (aside from the occassional and lucky 96% or 97%).

# %%
def KNN_find_best_k(inputList,_max):
    
    outputList = [pd.DataFrame(data={"X Variable(s)": [inputList,],
                                      "Avg Accuracy": 0.0,
                                      "SD of Accuracy": 0.0,
                                      "Sensitivity": 0.0,
                                      "Precision": 0.0,
                                      "F1-Score": 0.0,
                                      "Runtime": 0.0,
                                      "Confusion_Matrix": "none"})] #,"Real Specificity": [1,]
    
    for i in range(1,_max):
        
        tempList = []
        
        for j in range(10):
            tempList.append(ML_summary(inputList,neighbors.KNeighborsClassifier(n_neighbors = i)))
            
        tempList = pd.concat(tempList, ignore_index=True)

        outputList.append(tempList.head(1))

    outputList = pd.concat(outputList, ignore_index=True)
    
    return outputList.sort_values(by = "F1-Score",ascending=False)

KNN_find_best_k(["deldel_G3","iso_point"],5)
# Out:
#                 X Variable(s)  Avg Accuracy  SD of Accuracy  Sensitivity  \
# 3  ['deldel_G3', 'iso_point']        0.9400        0.086023     1.000000
# 2  ['deldel_G3', 'iso_point']        0.9275        0.083629     1.000000
# 4  ['deldel_G3', 'iso_point']        0.8875        0.114428     1.000000
# 1  ['deldel_G3', 'iso_point']        0.8650        0.088176     0.918288
# 0      [deldel_G3, iso_point]        0.0000        0.000000     0.000000
#
#    Precision  F1-Score   Runtime         Confusion_Matrix  \
# 3   0.916376  0.956364  0.130837  [[263   0]\n [ 24 113]]
# 2   0.903654  0.949389  0.129888  [[272   0]\n [ 29  99]]
# 4   0.851974  0.920071  0.143085  [[259   0]\n [ 45  96]]
# 1   0.877323  0.897338  0.148689  [[236  21]\n [ 33 110]]
# 0   0.000000  0.000000  0.000000                     none
#
#                                  Model
# 3  KNeighborsClassifier(n_neighbors=3)
# 2  KNeighborsClassifier(n_neighbors=2)
# 4  KNeighborsClassifier(n_neighbors=4)
# 1  KNeighborsClassifier(n_neighbors=1)
# 0                                  NaN

# %% [markdown]
# ### isoelectric point

# %%
ML_compare_variables([neighbors.KNeighborsClassifier(n_neighbors = 3)],[["iso_point", "pdel"],
                                                                        ["iso_point", "solv_area"],
                                                                        ["iso_point", "deldel_G1"],
                                                                        ["iso_point", "deldel_G2"],
                                                                        ["iso_point", "deldel_G3"],
                                                                        ["iso_point", "ogAA_letterCode"]])
# Out:
#                                  Model                     X Variable(s)  \
# 5  KNeighborsClassifier(n_neighbors=3)  ['iso_point', 'ogAA_letterCode']
# 4  KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'deldel_G3']
# 0  KNeighborsClassifier(n_neighbors=3)             ['iso_point', 'pdel']
# 2  KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'deldel_G1']
# 1  KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'solv_area']
# 3  KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'deldel_G2']
#
#    Avg Accuracy  SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 5        0.9575        0.058683          1.0   0.939716  0.968921  0.137418
# 4        0.9400        0.080000          1.0   0.915789  0.956044  0.130572
# 0        0.9375        0.085696          1.0   0.911972  0.953959  0.155871
# 2        0.9225        0.075788          1.0   0.888889  0.941176  0.127302
# 1        0.9175        0.086277          1.0   0.883392  0.938086  0.128799
# 3        0.8975        0.068875          1.0   0.862876  0.926391  0.166820
#
#           Confusion_Matrix
# 5  [[265   0]\n [ 17 118]]
# 4  [[261   0]\n [ 24 115]]
# 0  [[259   0]\n [ 25 116]]
# 2  [[248   0]\n [ 31 121]]
# 1  [[250   0]\n [ 33 117]]
# 3  [[258   0]\n [ 41 101]]

# %% [markdown]
# ### original AA letter

# %%
ML_compare_variables([neighbors.KNeighborsClassifier(n_neighbors = 3)],[["iso_point", "ogAA_letterCode"],
                                                                        ["pdel", "ogAA_letterCode"],
                                                                        ["solv_area", "ogAA_letterCode"],
                                                                        ["deldel_G3", "ogAA_letterCode"],
                                                                        ["deldel_G2", "ogAA_letterCode"],
                                                                        ["deldel_G1", "ogAA_letterCode"]])
# Out:
#                                  Model                     X Variable(s)  \
# 0  KNeighborsClassifier(n_neighbors=3)  ['iso_point', 'ogAA_letterCode']
# 1  KNeighborsClassifier(n_neighbors=3)       ['pdel', 'ogAA_letterCode']
# 2  KNeighborsClassifier(n_neighbors=3)  ['solv_area', 'ogAA_letterCode']
# 5  KNeighborsClassifier(n_neighbors=3)  ['deldel_G1', 'ogAA_letterCode']
# 3  KNeighborsClassifier(n_neighbors=3)  ['deldel_G3', 'ogAA_letterCode']
# 4  KNeighborsClassifier(n_neighbors=3)  ['deldel_G2', 'ogAA_letterCode']
#
#    Avg Accuracy  SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 0        0.9650        0.057228     1.000000   0.947566  0.973077  0.219670
# 1        0.8275        0.124474     0.882591   0.844961  0.863366  0.187029
# 2        0.7275        0.132264     0.812261   0.779412  0.795497  0.220844
# 5        0.7125        0.118717     0.772201   0.781250  0.776699  0.210835
# 3        0.6850        0.131434     0.780488   0.727273  0.752941  0.172802
# 4        0.6625        0.149478     0.765625   0.723247  0.743833  0.257036
#
#           Confusion_Matrix
# 0  [[253   0]\n [ 14 133]]
# 1  [[218  29]\n [ 40 113]]
# 2  [[212  49]\n [ 60  79]]
# 5  [[200  59]\n [ 56  85]]
# 3  [[192  54]\n [ 72  82]]
# 4  [[196  60]\n [ 75  69]]

# %% [markdown]
# ### $\Delta$$\Delta$G's

# %%
ML_compare_variables([neighbors.KNeighborsClassifier(n_neighbors = 3)],[["deldel_G3", "iso_point"],
                                                                        ["deldel_G3", "pdel"],
                                                                        ["deldel_G3", "ogAA_letterCode"],
                                                                        ["deldel_G3", "solv_area"]])
# Out:
#                                  Model                     X Variable(s)  \
# 0  KNeighborsClassifier(n_neighbors=3)        ['deldel_G3', 'iso_point']
# 1  KNeighborsClassifier(n_neighbors=3)             ['deldel_G3', 'pdel']
# 2  KNeighborsClassifier(n_neighbors=3)  ['deldel_G3', 'ogAA_letterCode']
# 3  KNeighborsClassifier(n_neighbors=3)        ['deldel_G3', 'solv_area']
#
#    Avg Accuracy  SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 0        0.9175        0.102195     1.000000   0.882143  0.937381  0.270752
# 1        0.8575        0.097179     0.879245   0.903101  0.891013  0.251880
# 2        0.6775        0.145752     0.813230   0.720690  0.764168  0.306387
# 3        0.6525        0.113990     0.798479   0.709459  0.751342  0.256802
#
#           Confusion_Matrix
# 0  [[247   0]\n [ 33 120]]
# 1  [[233  32]\n [ 25 110]]
# 2  [[209  48]\n [ 81  62]]
# 3  [[210  53]\n [ 86  51]]

# %% [markdown]
# ### pdel

# %%
ML_compare_variables([neighbors.KNeighborsClassifier(n_neighbors = 3)],[["pdel", "iso_point"],
                                                                        ["pdel", "deldel_G1"],
                                                                        ["pdel", "deldel_G2"],
                                                                        ["pdel", "deldel_G3"],
                                                                        ["pdel", "solv_area"]])
# Out:
#                                  Model          X Variable(s)  Avg Accuracy  \
# 0  KNeighborsClassifier(n_neighbors=3)  ['pdel', 'iso_point']        0.9475
# 1  KNeighborsClassifier(n_neighbors=3)  ['pdel', 'deldel_G1']        0.8400
# 4  KNeighborsClassifier(n_neighbors=3)  ['pdel', 'solv_area']        0.8225
# 3  KNeighborsClassifier(n_neighbors=3)  ['pdel', 'deldel_G3']        0.8275
# 2  KNeighborsClassifier(n_neighbors=3)  ['pdel', 'deldel_G2']        0.8150
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 0        0.067035     1.000000   0.924460  0.960748  0.135181
# 1        0.091652     0.905138   0.851301  0.877395  0.133344
# 4        0.096144     0.885375   0.842105  0.863198  0.137828
# 3        0.086566     0.850980   0.875000  0.862823  0.123834
# 2        0.096307     0.883721   0.838235  0.860377  0.177710
#
#           Confusion_Matrix
# 0  [[257   0]\n [ 21 122]]
# 1  [[229  24]\n [ 40 107]]
# 4  [[224  29]\n [ 42 105]]
# 3  [[217  38]\n [ 31 114]]
# 2  [[228  30]\n [ 44  98]]

# %% [markdown]
# ### trios

# %%
ML_compare_variables([neighbors.KNeighborsClassifier(n_neighbors = 3)],[["pdel", "iso_point", "deldel_G3"],
                                                                        ["pdel", "iso_point", "solv_area"],
                                                                        ["pdel", "iso_point", "ogAA_letterCode"],
                                                                        ["pdel", "iso_point", "deldel_G1"],
                                                                        ["pdel", "iso_point", "deldel_G2"]])
# Out:
#                                  Model  \
# 2  KNeighborsClassifier(n_neighbors=3)
# 3  KNeighborsClassifier(n_neighbors=3)
# 0  KNeighborsClassifier(n_neighbors=3)
# 4  KNeighborsClassifier(n_neighbors=3)
# 1  KNeighborsClassifier(n_neighbors=3)
#
#                               X Variable(s)  Avg Accuracy  SD of Accuracy  \
# 2  ['pdel', 'iso_point', 'ogAA_letterCode']        0.9475        0.059108
# 3        ['pdel', 'iso_point', 'deldel_G1']        0.9475        0.086566
# 0        ['pdel', 'iso_point', 'deldel_G3']        0.9425        0.080273
# 4        ['pdel', 'iso_point', 'deldel_G2']        0.9325        0.078700
# 1        ['pdel', 'iso_point', 'solv_area']        0.9200        0.090000
#
#    Sensitivity  Precision  F1-Score   Runtime         Confusion_Matrix
# 2          1.0   0.929054  0.963222  0.178630  [[275   0]\n [ 21 104]]
# 3          1.0   0.928328  0.962832  0.143992  [[272   0]\n [ 21 107]]
# 0          1.0   0.917857  0.957169  0.165192  [[257   0]\n [ 23 120]]
# 4          1.0   0.906574  0.950998  0.140353  [[262   0]\n [ 27 111]]
# 1          1.0   0.892617  0.943262  0.138490  [[266   0]\n [ 32 102]]

# %% [markdown]
# ### all the duos

# %%
ML_compare_variables([neighbors.KNeighborsClassifier(n_neighbors = 3)],[["iso_point", "pdel"],
                                                     ["iso_point", "solv_area"],
                                                     ["iso_point", "deldel_G1"],
                                                     ["iso_point", "deldel_G2"],
                                                     ["iso_point", "deldel_G3"],
                                                     ["iso_point", "ogAA_letterCode"],
                                                     ["pdel", "ogAA_letterCode"],
                                                     ["solv_area", "ogAA_letterCode"],
                                                     ["deldel_G3", "ogAA_letterCode"],
                                                     ["deldel_G2", "ogAA_letterCode"],
                                                     ["deldel_G1", "ogAA_letterCode"],
                                                     ["pdel", "deldel_G1"],
                                                     ["pdel", "deldel_G2"],
                                                     ["pdel", "deldel_G3"],
                                                     ["pdel", "solv_area"],
                                                     ["pdel", "iso_point"],
                                                     ["solv_area", "deldel_G1"],
                                                     ["solv_area", "deldel_G2"],
                                                     ["solv_area", "deldel_G3"],
                                                     ["solv_area", "pdel"],
                                                     ["solv_area", "iso_point"]])
# Out:
#                                   Model                     X Variable(s)  \
# 0   KNeighborsClassifier(n_neighbors=3)             ['iso_point', 'pdel']
# 4   KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'deldel_G3']
# 20  KNeighborsClassifier(n_neighbors=3)        ['solv_area', 'iso_point']
# 15  KNeighborsClassifier(n_neighbors=3)             ['pdel', 'iso_point']
# 2   KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'deldel_G1']
# 1   KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'solv_area']
# 5   KNeighborsClassifier(n_neighbors=3)  ['iso_point', 'ogAA_letterCode']
# 3   KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'deldel_G2']
# 14  KNeighborsClassifier(n_neighbors=3)             ['pdel', 'solv_area']
# 6   KNeighborsClassifier(n_neighbors=3)       ['pdel', 'ogAA_letterCode']
# 11  KNeighborsClassifier(n_neighbors=3)             ['pdel', 'deldel_G1']
# 13  KNeighborsClassifier(n_neighbors=3)             ['pdel', 'deldel_G3']
# 12  KNeighborsClassifier(n_neighbors=3)             ['pdel', 'deldel_G2']
# 19  KNeighborsClassifier(n_neighbors=3)             ['solv_area', 'pdel']
# 10  KNeighborsClassifier(n_neighbors=3)  ['deldel_G1', 'ogAA_letterCode']
# 7   KNeighborsClassifier(n_neighbors=3)  ['solv_area', 'ogAA_letterCode']
# 9   KNeighborsClassifier(n_neighbors=3)  ['deldel_G2', 'ogAA_letterCode']
# 17  KNeighborsClassifier(n_neighbors=3)        ['solv_area', 'deldel_G2']
# 8   KNeighborsClassifier(n_neighbors=3)  ['deldel_G3', 'ogAA_letterCode']
# 18  KNeighborsClassifier(n_neighbors=3)        ['solv_area', 'deldel_G3']
# 16  KNeighborsClassifier(n_neighbors=3)        ['solv_area', 'deldel_G1']
#
#     Avg Accuracy  SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 0         0.9550        0.058949     1.000000   0.936170  0.967033  0.151299
# 4         0.9450        0.070534     1.000000   0.922261  0.959559  0.156136
# 20        0.9350        0.096307     1.000000   0.912162  0.954064  0.143282
# 15        0.9400        0.091652     1.000000   0.911111  0.953488  0.148709
# 2         0.9350        0.072629     1.000000   0.910345  0.953069  0.167611
# 1         0.9300        0.092736     1.000000   0.905085  0.950178  0.135370
# 5         0.9300        0.095394     1.000000   0.903114  0.949091  0.153571
# 3         0.9275        0.074120     1.000000   0.902027  0.948490  0.165324
# 14        0.8600        0.070000     0.890152   0.896947  0.893536  0.124204
# 6         0.8500        0.097468     0.894942   0.874525  0.884615  0.151983
# 11        0.8450        0.086458     0.912698   0.851852  0.881226  0.143845
# 13        0.8450        0.116082     0.876923   0.883721  0.880309  0.140275
# 12        0.8275        0.099969     0.874510   0.857692  0.866019  0.121424
# 19        0.8300        0.102956     0.852140   0.879518  0.865613  0.150441
# 10        0.7425        0.120182     0.814516   0.779923  0.796844  0.127134
# 7         0.7150        0.106184     0.803774   0.774545  0.788889  0.142720
# 9         0.7150        0.158981     0.770909   0.806084  0.788104  0.133052
# 17        0.6825        0.142982     0.814229   0.720280  0.764378  0.152486
# 8         0.6750        0.121963     0.771863   0.743590  0.757463  0.149573
# 18        0.6475        0.130360     0.764925   0.724382  0.744102  0.165518
# 16        0.6025        0.115081     0.792969   0.656958  0.718584  0.145946
#
#            Confusion_Matrix
# 0   [[264   0]\n [ 18 118]]
# 4   [[261   0]\n [ 22 117]]
# 20  [[270   0]\n [ 26 104]]
# 15  [[246   0]\n [ 24 130]]
# 2   [[264   0]\n [ 26 110]]
# 1   [[267   0]\n [ 28 105]]
# 5   [[261   0]\n [ 28 111]]
# 3   [[267   0]\n [ 29 104]]
# 14  [[235  29]\n [ 27 109]]
# 6   [[230  27]\n [ 33 110]]
# 11  [[230  22]\n [ 40 108]]
# 13  [[228  32]\n [ 30 110]]
# 12  [[223  32]\n [ 37 108]]
# 19  [[219  38]\n [ 30 113]]
# 10  [[202  46]\n [ 57  95]]
# 7   [[213  52]\n [ 62  73]]
# 9   [[212  63]\n [ 51  74]]
# 17  [[206  47]\n [ 80  67]]
# 8   [[203  60]\n [ 70  67]]
# 18  [[205  63]\n [ 78  54]]
# 16  [[203  53]\n [106  38]]

# %% [markdown]
# ### duos and trios

# %%
ML_compare_variables([neighbors.KNeighborsClassifier(n_neighbors = 3)],[["iso_point", "pdel"],
                                                     ["iso_point", "solv_area"],
                                                     ["iso_point", "deldel_G1"],
                                                     ["iso_point", "deldel_G2"],
                                                     ["iso_point", "deldel_G3"],
                                                     ["iso_point", "ogAA_letterCode"],
                                                     ["pdel", "ogAA_letterCode"],
                                                     ["solv_area", "ogAA_letterCode"],
                                                     ["deldel_G3", "ogAA_letterCode"],
                                                     ["deldel_G2", "ogAA_letterCode"],
                                                     ["deldel_G1", "ogAA_letterCode"],
                                                     ["pdel", "deldel_G1"],
                                                     ["pdel", "deldel_G2"],
                                                     ["pdel", "deldel_G3"],
                                                     ["pdel", "solv_area"],
                                                     ["pdel", "iso_point"],
                                                     ["solv_area", "deldel_G1"],
                                                     ["solv_area", "deldel_G2"],
                                                     ["solv_area", "deldel_G3"],
                                                     ["solv_area", "pdel"],
                                                     ["solv_area", "iso_point"],
                                                     ["pdel", "iso_point", "deldel_G3"],
                                                     ["pdel", "iso_point", "solv_area"],
                                                     ["pdel", "iso_point", "ogAA_letterCode"],
                                                     ["pdel", "iso_point", "deldel_G1"],
                                                     ["pdel", "iso_point", "deldel_G2"]])
# Out:
#                                   Model  \
# 15  KNeighborsClassifier(n_neighbors=3)
# 2   KNeighborsClassifier(n_neighbors=3)
# 20  KNeighborsClassifier(n_neighbors=3)
# 23  KNeighborsClassifier(n_neighbors=3)
# 0   KNeighborsClassifier(n_neighbors=3)
# 4   KNeighborsClassifier(n_neighbors=3)
# 24  KNeighborsClassifier(n_neighbors=3)
# 22  KNeighborsClassifier(n_neighbors=3)
# 5   KNeighborsClassifier(n_neighbors=3)
# 21  KNeighborsClassifier(n_neighbors=3)
# 25  KNeighborsClassifier(n_neighbors=3)
# 3   KNeighborsClassifier(n_neighbors=3)
# 1   KNeighborsClassifier(n_neighbors=3)
# 6   KNeighborsClassifier(n_neighbors=3)
# 11  KNeighborsClassifier(n_neighbors=3)
# 19  KNeighborsClassifier(n_neighbors=3)
# 14  KNeighborsClassifier(n_neighbors=3)
# 12  KNeighborsClassifier(n_neighbors=3)
# 13  KNeighborsClassifier(n_neighbors=3)
# 10  KNeighborsClassifier(n_neighbors=3)
# 9   KNeighborsClassifier(n_neighbors=3)
# 17  KNeighborsClassifier(n_neighbors=3)
# 7   KNeighborsClassifier(n_neighbors=3)
# 8   KNeighborsClassifier(n_neighbors=3)
# 18  KNeighborsClassifier(n_neighbors=3)
# 16  KNeighborsClassifier(n_neighbors=3)
#
#                                X Variable(s)  Avg Accuracy  SD of Accuracy  \
# 15                     ['pdel', 'iso_point']        0.9550        0.054544
# 2                 ['iso_point', 'deldel_G1']        0.9550        0.058949
# 20                ['solv_area', 'iso_point']        0.9525        0.067035
# 23  ['pdel', 'iso_point', 'ogAA_letterCode']        0.9475        0.054715
# 0                      ['iso_point', 'pdel']        0.9425        0.080273
# 4                 ['iso_point', 'deldel_G3']        0.9400        0.083066
# 24        ['pdel', 'iso_point', 'deldel_G1']        0.9400        0.058310
# 22        ['pdel', 'iso_point', 'solv_area']        0.9325        0.068511
# 5           ['iso_point', 'ogAA_letterCode']        0.9325        0.064759
# 21        ['pdel', 'iso_point', 'deldel_G3']        0.9275        0.070666
# 25        ['pdel', 'iso_point', 'deldel_G2']        0.9250        0.108972
# 3                 ['iso_point', 'deldel_G2']        0.9050        0.080467
# 1                 ['iso_point', 'solv_area']        0.9050        0.102347
# 6                ['pdel', 'ogAA_letterCode']        0.8850        0.110793
# 11                     ['pdel', 'deldel_G1']        0.8725        0.094835
# 19                     ['solv_area', 'pdel']        0.8400        0.101980
# 14                     ['pdel', 'solv_area']        0.8375        0.108829
# 12                     ['pdel', 'deldel_G2']        0.8325        0.114864
# 13                     ['pdel', 'deldel_G3']        0.8275        0.089408
# 10          ['deldel_G1', 'ogAA_letterCode']        0.7425        0.130168
# 9           ['deldel_G2', 'ogAA_letterCode']        0.7175        0.151472
# 17                ['solv_area', 'deldel_G2']        0.6775        0.135069
# 7           ['solv_area', 'ogAA_letterCode']        0.6700        0.145258
# 8           ['deldel_G3', 'ogAA_letterCode']        0.6625        0.157619
# 18                ['solv_area', 'deldel_G3']        0.6225        0.129398
# 16                ['solv_area', 'deldel_G1']        0.5925        0.133018
#
#     Sensitivity  Precision  F1-Score   Runtime         Confusion_Matrix
# 15     1.000000   0.934307  0.966038  0.190341  [[256   0]\n [ 18 126]]
# 2      1.000000   0.934066  0.965909  0.155681  [[255   0]\n [ 18 127]]
# 20     1.000000   0.934028  0.965889  0.161909  [[269   0]\n [ 19 112]]
# 23     1.000000   0.927083  0.962162  0.199744  [[267   0]\n [ 21 112]]
# 0      1.000000   0.920415  0.958559  0.152128  [[266   0]\n [ 23 111]]
# 4      1.000000   0.915493  0.955882  0.156344  [[260   0]\n [ 24 116]]
# 24     1.000000   0.914286  0.955224  0.231688  [[256   0]\n [ 24 120]]
# 22     1.000000   0.905263  0.950276  0.192069  [[258   0]\n [ 27 115]]
# 5      1.000000   0.900369  0.947573  0.157122  [[244   0]\n [ 27 129]]
# 21     1.000000   0.899654  0.947177  0.166522  [[260   0]\n [ 29 111]]
# 25     0.995951   0.894545  0.942529  0.236208  [[246   1]\n [ 29 124]]
# 3      1.000000   0.874172  0.932862  0.162718  [[264   0]\n [ 38  98]]
# 1      0.995984   0.870175  0.928839  0.179116  [[248   1]\n [ 37 114]]
# 6      0.938931   0.891304  0.914498  0.130867  [[246  16]\n [ 30 108]]
# 11     0.937743   0.873188  0.904315  0.207148  [[241  16]\n [ 35 108]]
# 19     0.865672   0.892308  0.878788  0.148121  [[232  36]\n [ 28 104]]
# 14     0.854015   0.903475  0.878049  0.187422  [[234  40]\n [ 25 101]]
# 12     0.891051   0.854478  0.872381  0.174774  [[229  28]\n [ 39 104]]
# 13     0.876923   0.860377  0.868571  0.171287  [[228  32]\n [ 37 103]]
# 10     0.813953   0.792453  0.803059  0.177091  [[210  48]\n [ 55  87]]
# 9      0.799228   0.772388  0.785579  0.203814  [[207  52]\n [ 61  80]]
# 17     0.790614   0.755172  0.772487  0.160805  [[219  58]\n [ 71  52]]
# 7      0.756654   0.745318  0.750943  0.191814  [[199  64]\n [ 68  69]]
# 8      0.758491   0.738971  0.748603  0.201520  [[201  64]\n [ 71  64]]
# 18     0.781746   0.672355  0.722936  0.147853  [[197  55]\n [ 96  52]]
# 16     0.750000   0.653979  0.698706  0.168122  [[189  63]\n [100  48]]

# %% [markdown]
# # LDA:
# What applied to logistic regression models applied to LDA, or Linear Discriminant Analysis, models as well. Since LDA models work linearly, we predicted that they would not be able to best classify our data, especially when using the isoelectric point values. Testing the same combinations of covariates applied to previous models, we found that the best LDA model only had an average accuracy of 87.25%, F1 score of 0.91, sensitivity of 0.91, and precision of 0.90.

# %% [markdown]
# ### duos

# %%
ML_compare_variables([LinearDiscriminantAnalysis()],[["iso_point", "pdel"],
                                                     ["iso_point", "solv_area"],
                                                     ["iso_point", "deldel_G1"],
                                                     ["iso_point", "deldel_G2"],
                                                     ["iso_point", "deldel_G3"],
                                                     ["iso_point", "ogAA_letterCode"],
                                                     ["pdel", "ogAA_letterCode"],
                                                     ["solv_area", "ogAA_letterCode"],
                                                     ["deldel_G3", "ogAA_letterCode"],
                                                     ["deldel_G2", "ogAA_letterCode"],
                                                     ["deldel_G1", "ogAA_letterCode"],
                                                     ["pdel", "deldel_G1"],
                                                     ["pdel", "deldel_G2"],
                                                     ["pdel", "deldel_G3"],
                                                     ["pdel", "solv_area"],
                                                     ["pdel", "iso_point"],
                                                     ["solv_area", "deldel_G1"],
                                                     ["solv_area", "deldel_G2"],
                                                     ["solv_area", "deldel_G3"],
                                                     ["solv_area", "pdel"],
                                                     ["solv_area", "iso_point"]])
# Out:
#                            Model                     X Variable(s)  \
# 11  LinearDiscriminantAnalysis()             ['pdel', 'deldel_G1']
# 13  LinearDiscriminantAnalysis()             ['pdel', 'deldel_G3']
# 12  LinearDiscriminantAnalysis()             ['pdel', 'deldel_G2']
# 19  LinearDiscriminantAnalysis()             ['solv_area', 'pdel']
# 6   LinearDiscriminantAnalysis()       ['pdel', 'ogAA_letterCode']
# 14  LinearDiscriminantAnalysis()             ['pdel', 'solv_area']
# 15  LinearDiscriminantAnalysis()             ['pdel', 'iso_point']
# 0   LinearDiscriminantAnalysis()             ['iso_point', 'pdel']
# 4   LinearDiscriminantAnalysis()        ['iso_point', 'deldel_G3']
# 9   LinearDiscriminantAnalysis()  ['deldel_G2', 'ogAA_letterCode']
# 7   LinearDiscriminantAnalysis()  ['solv_area', 'ogAA_letterCode']
# 2   LinearDiscriminantAnalysis()        ['iso_point', 'deldel_G1']
# 20  LinearDiscriminantAnalysis()        ['solv_area', 'iso_point']
# 3   LinearDiscriminantAnalysis()        ['iso_point', 'deldel_G2']
# 18  LinearDiscriminantAnalysis()        ['solv_area', 'deldel_G3']
# 8   LinearDiscriminantAnalysis()  ['deldel_G3', 'ogAA_letterCode']
# 1   LinearDiscriminantAnalysis()        ['iso_point', 'solv_area']
# 5   LinearDiscriminantAnalysis()  ['iso_point', 'ogAA_letterCode']
# 17  LinearDiscriminantAnalysis()        ['solv_area', 'deldel_G2']
# 10  LinearDiscriminantAnalysis()  ['deldel_G1', 'ogAA_letterCode']
# 16  LinearDiscriminantAnalysis()        ['solv_area', 'deldel_G1']
#
#     Avg Accuracy  SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 11        0.8750        0.101858     0.891791   0.919231  0.905303  0.146610
# 13        0.8700        0.090000     0.902985   0.902985  0.902985  0.137523
# 12        0.8675        0.105801     0.903101   0.892720  0.897881  0.126438
# 19        0.8625        0.104133     0.892720   0.896154  0.894434  0.129302
# 6         0.8375        0.123870     0.883721   0.866920  0.875240  0.130291
# 14        0.8250        0.117792     0.873950   0.838710  0.855967  0.155416
# 15        0.8025        0.131315     0.920949   0.797945  0.855046  0.122178
# 0         0.8100        0.151327     0.925311   0.793594  0.854406  0.130255
# 4         0.6750        0.115650     0.973485   0.676316  0.798137  0.110919
# 9         0.6425        0.124273     0.921053   0.667575  0.774092  0.141547
# 7         0.6375        0.115515     0.912698   0.651558  0.760331  0.134568
# 2         0.6250        0.113468     0.959514   0.628647  0.759615  0.129067
# 20        0.6000        0.114018     0.876866   0.649171  0.746032  0.152986
# 3         0.6000        0.136015     0.946939   0.612137  0.743590  0.135475
# 18        0.6000        0.139642     0.874525   0.644258  0.741935  0.122144
# 8         0.6075        0.153928     0.839552   0.663717  0.741351  0.126506
# 1         0.5950        0.116082     0.916000   0.618919  0.738710  0.151880
# 5         0.5975        0.112888     0.874510   0.633523  0.734761  0.133724
# 17        0.5800        0.136382     0.898833   0.619303  0.733333  0.138797
# 10        0.5650        0.142390     0.849421   0.619718  0.716612  0.164851
# 16        0.5600        0.120000     0.835878   0.622159  0.713355  0.119320
#
#            Confusion_Matrix
# 11  [[239  29]\n [ 21 111]]
# 13  [[242  26]\n [ 26 106]]
# 12  [[233  25]\n [ 28 114]]
# 19  [[233  28]\n [ 27 112]]
# 6   [[228  30]\n [ 35 107]]
# 14  [[208  30]\n [ 40 122]]
# 15  [[233  20]\n [ 59  88]]
# 0   [[223  18]\n [ 58 101]]
# 4   [[257   7]\n [123  13]]
# 9   [[245  21]\n [122  12]]
# 7   [[230  22]\n [123  25]]
# 2   [[237  10]\n [140  13]]
# 20  [[235  33]\n [127   5]]
# 3   [[232  13]\n [147   8]]
# 18  [[230  33]\n [127  10]]
# 8   [[225  43]\n [114  18]]
# 1   [[229  21]\n [141   9]]
# 5   [[223  32]\n [129  16]]
# 17  [[231  26]\n [142   1]]
# 10  [[220  39]\n [135   6]]
# 16  [[219  43]\n [133   5]]

# %% [markdown]
# ### trios

# %%
ML_compare_variables([LinearDiscriminantAnalysis()],[["pdel", "iso_point", "deldel_G3"],
                                                     ["pdel", "iso_point", "solv_area"],
                                                     ["pdel", "iso_point", "ogAA_letterCode"],
                                                     ["pdel", "iso_point", "deldel_G1"],
                                                     ["pdel", "iso_point", "deldel_G2"]])
# Out:
#                           Model                             X Variable(s)  \
# 3  LinearDiscriminantAnalysis()        ['pdel', 'iso_point', 'deldel_G1']
# 1  LinearDiscriminantAnalysis()        ['pdel', 'iso_point', 'solv_area']
# 4  LinearDiscriminantAnalysis()        ['pdel', 'iso_point', 'deldel_G2']
# 2  LinearDiscriminantAnalysis()  ['pdel', 'iso_point', 'ogAA_letterCode']
# 0  LinearDiscriminantAnalysis()        ['pdel', 'iso_point', 'deldel_G3']
#
#    Avg Accuracy  SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 3        0.8325        0.095884     0.885932   0.862963  0.874296  0.144218
# 1        0.8100        0.128062     0.907749   0.828283  0.866197  0.118183
# 4        0.8175        0.118084     0.914397   0.821678  0.865562  0.147608
# 2        0.8050        0.135923     0.866935   0.826923  0.846457  0.157242
# 0        0.7600        0.144568     0.897959   0.756014  0.820896  0.147014
#
#           Confusion_Matrix
# 3  [[233  30]\n [ 37 100]]
# 1  [[246  25]\n [ 51  78]]
# 4  [[235  22]\n [ 51  92]]
# 2  [[215  33]\n [ 45 107]]
# 0  [[220  25]\n [ 71  84]]

# %% [markdown]
# ### duos and trios

# %%
ML_compare_variables([LinearDiscriminantAnalysis()],[["iso_point", "pdel"],
                                                     ["iso_point", "solv_area"],
                                                     ["iso_point", "deldel_G1"],
                                                     ["iso_point", "deldel_G2"],
                                                     ["iso_point", "deldel_G3"],
                                                     ["iso_point", "ogAA_letterCode"],
                                                     ["pdel", "ogAA_letterCode"],
                                                     ["solv_area", "ogAA_letterCode"],
                                                     ["deldel_G3", "ogAA_letterCode"],
                                                     ["deldel_G2", "ogAA_letterCode"],
                                                     ["deldel_G1", "ogAA_letterCode"],
                                                     ["pdel", "deldel_G1"],
                                                     ["pdel", "deldel_G2"],
                                                     ["pdel", "deldel_G3"],
                                                     ["pdel", "solv_area"],
                                                     ["pdel", "iso_point"],
                                                     ["solv_area", "deldel_G1"],
                                                     ["solv_area", "deldel_G2"],
                                                     ["solv_area", "deldel_G3"],
                                                     ["solv_area", "pdel"],
                                                     ["solv_area", "iso_point"],
                                                     ["pdel", "iso_point", "deldel_G3"],
                                                     ["pdel", "iso_point", "solv_area"],
                                                     ["pdel", "iso_point", "ogAA_letterCode"],
                                                     ["pdel", "iso_point", "deldel_G1"],
                                                     ["pdel", "iso_point", "deldel_G2"]])
# Out:
#                            Model                             X Variable(s)  \
# 19  LinearDiscriminantAnalysis()                     ['solv_area', 'pdel']
# 14  LinearDiscriminantAnalysis()                     ['pdel', 'solv_area']
# 6   LinearDiscriminantAnalysis()               ['pdel', 'ogAA_letterCode']
# 11  LinearDiscriminantAnalysis()                     ['pdel', 'deldel_G1']
# 13  LinearDiscriminantAnalysis()                     ['pdel', 'deldel_G3']
# 25  LinearDiscriminantAnalysis()        ['pdel', 'iso_point', 'deldel_G2']
# 15  LinearDiscriminantAnalysis()                     ['pdel', 'iso_point']
# 23  LinearDiscriminantAnalysis()  ['pdel', 'iso_point', 'ogAA_letterCode']
# 12  LinearDiscriminantAnalysis()                     ['pdel', 'deldel_G2']
# 24  LinearDiscriminantAnalysis()        ['pdel', 'iso_point', 'deldel_G1']
# 22  LinearDiscriminantAnalysis()        ['pdel', 'iso_point', 'solv_area']
# 0   LinearDiscriminantAnalysis()                     ['iso_point', 'pdel']
# 21  LinearDiscriminantAnalysis()        ['pdel', 'iso_point', 'deldel_G3']
# 3   LinearDiscriminantAnalysis()                ['iso_point', 'deldel_G2']
# 4   LinearDiscriminantAnalysis()                ['iso_point', 'deldel_G3']
# 2   LinearDiscriminantAnalysis()                ['iso_point', 'deldel_G1']
# 1   LinearDiscriminantAnalysis()                ['iso_point', 'solv_area']
# 8   LinearDiscriminantAnalysis()          ['deldel_G3', 'ogAA_letterCode']
# 20  LinearDiscriminantAnalysis()                ['solv_area', 'iso_point']
# 7   LinearDiscriminantAnalysis()          ['solv_area', 'ogAA_letterCode']
# 18  LinearDiscriminantAnalysis()                ['solv_area', 'deldel_G3']
# 10  LinearDiscriminantAnalysis()          ['deldel_G1', 'ogAA_letterCode']
# 9   LinearDiscriminantAnalysis()          ['deldel_G2', 'ogAA_letterCode']
# 17  LinearDiscriminantAnalysis()                ['solv_area', 'deldel_G2']
# 5   LinearDiscriminantAnalysis()          ['iso_point', 'ogAA_letterCode']
# 16  LinearDiscriminantAnalysis()                ['solv_area', 'deldel_G1']
#
#     Avg Accuracy  SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 19        0.8725        0.083629     0.912088   0.902174  0.907104  0.149611
# 14        0.8550        0.126392     0.884328   0.897727  0.890977  0.127884
# 6         0.8475        0.111775     0.895131   0.878676  0.886827  0.123377
# 11        0.8475        0.099969     0.879377   0.882812  0.881092  0.129686
# 13        0.8300        0.097980     0.874539   0.874539  0.874539  0.148632
# 25        0.8300        0.110000     0.911538   0.840426  0.874539  0.116591
# 15        0.8325        0.123263     0.935743   0.820423  0.874296  0.141495
# 23        0.8225        0.108369     0.869091   0.872263  0.870674  0.143389
# 12        0.8325        0.100964     0.870588   0.867188  0.868885  0.115613
# 24        0.8150        0.129518     0.897338   0.833922  0.864469  0.154713
# 22        0.8000        0.104881     0.927203   0.798680  0.858156  0.157810
# 0         0.8050        0.118216     0.894118   0.817204  0.853933  0.125841
# 21        0.7775        0.138722     0.888031   0.793103  0.837887  0.159928
# 3         0.6800        0.116619     0.985019   0.679587  0.804281  0.137907
# 4         0.6725        0.099969     0.956204   0.687664  0.800000  0.148749
# 2         0.6700        0.116619     0.976923   0.668421  0.793750  0.117327
# 1         0.6550        0.111692     0.874126   0.710227  0.783699  0.139398
# 8         0.6275        0.120390     0.864469   0.678161  0.760064  0.127807
# 20        0.6075        0.131125     0.923695   0.625000  0.745543  0.119381
# 7         0.6150        0.127574     0.865385   0.654070  0.745033  0.133950
# 18        0.5975        0.140512     0.865385   0.641026  0.736498  0.147234
# 10        0.5800        0.130767     0.850575   0.632479  0.725490  0.154106
# 9         0.5775        0.147458     0.894309   0.606061  0.722496  0.113239
# 17        0.5550        0.143091     0.858824   0.606648  0.711039  0.120809
# 5         0.5650        0.117367     0.835294   0.617391  0.710000  0.114363
# 16        0.5500        0.144914     0.830116   0.612536  0.704918  0.115148
#
#            Confusion_Matrix
# 19  [[249  24]\n [ 27 100]]
# 14  [[237  31]\n [ 27 105]]
# 6   [[239  28]\n [ 33 100]]
# 11  [[226  31]\n [ 30 113]]
# 13  [[237  34]\n [ 34  95]]
# 25  [[237  23]\n [ 45  95]]
# 15  [[233  16]\n [ 51 100]]
# 23  [[239  36]\n [ 35  90]]
# 12  [[222  33]\n [ 34 111]]
# 24  [[236  27]\n [ 47  90]]
# 22  [[242  19]\n [ 61  78]]
# 0   [[228  27]\n [ 51  94]]
# 21  [[230  29]\n [ 60  81]]
# 3   [[263   4]\n [124   9]]
# 4   [[262  12]\n [119   7]]
# 2   [[254   6]\n [126  14]]
# 1   [[250  36]\n [102  12]]
# 8   [[236  37]\n [112  15]]
# 20  [[230  19]\n [138  13]]
# 7   [[225  35]\n [119  21]]
# 18  [[225  35]\n [126  14]]
# 10  [[222  39]\n [129  10]]
# 9   [[220  26]\n [143  11]]
# 17  [[219  36]\n [142   3]]
# 5   [[213  42]\n [132  13]]
# 16  [[215  44]\n [136   5]]

# %% [markdown]
# # Basic Decision Tree:
#
# 6 is best max_depth

# %%
def basticDT_find_best_k(inputList,_max):
    
    outputList = [pd.DataFrame(data={"X Variable(s)": [inputList,],
                                      "Avg Accuracy": 0.0,
                                      "SD of Accuracy": 0.0,
                                      "Sensitivity": 0.0,
                                      "Precision": 0.0,
                                      "F1-Score": 0.0,
                                      "Runtime": 0.0,
                                      "Confusion_Matrix": "none"})] #,"Real Specificity": [1,]
    
    for i in range(1,_max):
        
        tempList = []
        
        for j in range(20):
            tempList.append(ML_summary(inputList,DecisionTreeClassifier(max_depth=i)))
            
        tempList = pd.concat(tempList, ignore_index=True)

        outputList.append(tempList.head(1))

    outputList = pd.concat(outputList, ignore_index=True)
    
    return outputList.sort_values(by = "F1-Score",ascending=False)

basticDT_find_best_k(["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"],10)
# Out:
#                                        X Variable(s)  Avg Accuracy  \
# 2  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8700
# 6  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8775
# 7  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8600
# 8  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8575
# 4  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8650
# 5  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8550
# 3  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8550
# 9  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8400
# 1  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.7625
# 0  [pdel, iso_point, deldel_G1, deldel_G2, deldel...        0.0000
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 2        0.112250     0.914498   0.894545  0.904412  0.124251
# 6        0.101211     0.901575   0.905138  0.903353  0.124536
# 7        0.101980     0.903346   0.890110  0.896679  0.119770
# 8        0.099718     0.906015   0.882784  0.894249  0.122381
# 4        0.115217     0.890196   0.897233  0.893701  0.120866
# 5        0.126392     0.896552   0.883019  0.889734  0.119316
# 3        0.113908     0.887597   0.887597  0.887597  0.123866
# 9        0.091652     0.861660   0.882591  0.872000  0.120278
# 1        0.101704     0.836735   0.788462  0.811881  0.127687
# 0        0.000000     0.000000   0.000000  0.000000  0.000000
#
#           Confusion_Matrix                                Model
# 2  [[246  23]\n [ 29 102]]  DecisionTreeClassifier(max_depth=2)
# 6  [[229  25]\n [ 24 122]]  DecisionTreeClassifier(max_depth=6)
# 7  [[243  26]\n [ 30 101]]  DecisionTreeClassifier(max_depth=7)
# 8  [[241  25]\n [ 32 102]]  DecisionTreeClassifier(max_depth=8)
# 4  [[227  28]\n [ 26 119]]  DecisionTreeClassifier(max_depth=4)
# 5  [[234  27]\n [ 31 108]]  DecisionTreeClassifier(max_depth=5)
# 3  [[229  29]\n [ 29 113]]  DecisionTreeClassifier(max_depth=3)
# 9  [[218  35]\n [ 29 118]]  DecisionTreeClassifier(max_depth=9)
# 1  [[205  40]\n [ 55 100]]  DecisionTreeClassifier(max_depth=1)
# 0                     none                                  NaN

# %%
ML_summary(["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"],DecisionTreeClassifier(max_depth=6))
# Out:
#                                  Model  \
# 0  DecisionTreeClassifier(max_depth=6)
#
#                                        X Variable(s)  Avg Accuracy  \
# 0  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...         0.865
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 0        0.090967      0.88764   0.908046  0.897727  0.126963
#
#           Confusion_Matrix
# 0  [[237  30]\n [ 24 109]]

# %%
ML_compare_variables([DecisionTreeClassifier(max_depth=6)],[["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"]])

# %% [markdown]
# # Bagging Decision Tree:

# %%
ML_summary(["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"],BaggingClassifier())
# Out:
#                  Model                                      X Variable(s)  \
# 0  BaggingClassifier()  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...
#
#    Avg Accuracy  SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 0         0.855         0.09734     0.900383    0.88015  0.890152  2.007819
#
#           Confusion_Matrix
# 0  [[235  26]\n [ 32 107]]

# %%
ML_compare_variables([BaggingClassifier()],[["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"]])

# %% [markdown]
# # Random Forest:
# Best max_depth = 2

# %%
ML_compare_variables(
[RandomForestClassifier(max_depth=2)],[["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"]])

# %%
ML_summary(["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"],RandomForestClassifier(max_depth=2))
# Out:
#                                  Model  \
# 0  RandomForestClassifier(max_depth=2)
#
#                                        X Variable(s)  Avg Accuracy  \
# 0  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8875
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score    Runtime  \
# 0        0.084224     0.975806    0.86121  0.914934  13.268733
#
#           Confusion_Matrix
# 0  [[242   6]\n [ 39 113]]

# %% [markdown]
# # Ada Boosting Decision Tree:
# Best n_estimators = 5000
# Best learning_rate = 0.1

# %%
ML_compare_variables([AdaBoostClassifier(n_estimators=5000, learning_rate = 0.1)],[["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"]])

# %% [markdown]
# # GradientBoosting Decision Tree:
# Best n_estimators = 5000
# Best learning_rate = 0.1

# %%
ML_compare_variables([GradientBoostingClassifier(n_estimators = 5000, learning_rate = 0.1, max_depth = 4)],[["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"]])
# Out:
#                                                Model  \
# 0  GradientBoostingClassifier(max_depth=4, n_esti...
#
#                                        X Variable(s)  Avg Accuracy  \
# 0  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...          0.86
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score     Runtime  \
# 0        0.109087      0.92803   0.868794  0.897436  117.000379
#
#           Confusion_Matrix
# 0  [[245  19]\n [ 37  99]]

# %% [markdown]
# # Support Vector Classifier:
# Best kernal = "rbf" (default), 6 is best C
#
# The SVC models were the other group of promising models. After testing a variety of hyperparameters, we found that the best kernal for our dataset was "rbf," the default kernal, and that 6 was the best C, _____test___. On average, the model with the highest accuracy of around 96.75% had solvent area and isoelectric point as its covariates. The model also had a sensitivity of 1.0, a precision of approximately 0.95, and an F1-score of approximately 0.97. The solvent area being a strong predictor when paired with isoelectric point was a mild surprise. The model with isoelectric point and $\Delta$$\Delta$G2 as its covariates also trailed ever so slightly behind (with the same accuracy) the best SVC model. The model with isoelectric point and pdel as covariates also performed rather well, with an average accuracy of 94.25%, sensitivity of 1.0, precision of 0.92, and F1-score of 0.96. This reflects what was shown by the best performing KNN model, where pdel and isoelectric point have strong evidence as the numerical variables with the strongest predictive power.

# %%
def SVC_find_best_c(inputList,_max):
    
    outputList = [pd.DataFrame(data={"X Variable(s)": [inputList,],
                                      "Avg Accuracy": 0.0,
                                      "SD of Accuracy": 0.0,
                                      "Sensitivity": 0.0,
                                      "Precision": 0.0,
                                      "F1-Score": 0.0,
                                      "Runtime": 0.0,
                                      "Confusion_Matrix": "none"})] #,"Real Specificity": [1,]
    
    for i in range(1,_max):
        
        tempList = []
        
        for j in range(10):
            tempList.append(ML_summary(inputList,SVC(C=i, kernel='rbf')))
            
        tempList = pd.concat(tempList, ignore_index=True)

        outputList.append(tempList.head(1))

    outputList = pd.concat(outputList, ignore_index=True)
    
    return outputList.sort_values(by = "F1-Score",ascending=False)

SVC_find_best_c(["iso_point","pdel"],10)
# Out:
#            X Variable(s)  Avg Accuracy  SD of Accuracy  Sensitivity  \
# 2  ['iso_point', 'pdel']        0.9500        0.067082     0.992395
# 1  ['iso_point', 'pdel']        0.9475        0.049937     1.000000
# 4  ['iso_point', 'pdel']        0.9425        0.083329     0.984436
# 5  ['iso_point', 'pdel']        0.9400        0.058310     0.992424
# 9  ['iso_point', 'pdel']        0.9450        0.073993     0.983539
# 3  ['iso_point', 'pdel']        0.9375        0.065907     0.992248
# 6  ['iso_point', 'pdel']        0.9375        0.065907     0.984314
# 7  ['iso_point', 'pdel']        0.9350        0.069101     0.975610
# 8  ['iso_point', 'pdel']        0.9275        0.094835     0.977695
# 0      [iso_point, pdel]        0.0000        0.000000     0.000000
#
#    Precision  F1-Score   Runtime         Confusion_Matrix     Model
# 2   0.935484  0.963100  0.110021  [[261   2]\n [ 18 119]]  SVC(C=2)
# 1   0.923077  0.960000  0.120349  [[252   0]\n [ 21 127]]  SVC(C=1)
# 4   0.930147  0.956522  0.199236  [[253   4]\n [ 19 124]]  SVC(C=4)
# 5   0.922535  0.956204  0.180540  [[262   2]\n [ 22 114]]  SVC(C=5)
# 9   0.929961  0.956000  0.192021  [[239   4]\n [ 18 139]]  SVC(C=9)
# 3   0.917563  0.953445  0.224562  [[256   2]\n [ 23 119]]  SVC(C=3)
# 6   0.922794  0.952562  0.192807  [[251   4]\n [ 21 124]]  SVC(C=6)
# 7   0.923077  0.948617  0.141654  [[240   6]\n [ 20 134]]  SVC(C=7)
# 8   0.919580  0.947748  0.191243  [[263   6]\n [ 23 108]]  SVC(C=8)
# 0   0.000000  0.000000  0.000000                     none       NaN

# %%
ML_compare_variables([SVC(C=6, kernel='linear'),SVC(C=6, kernel='poly'),SVC(C=6, kernel='rbf'),SVC(C=6, kernel='sigmoid')],[["iso_point","pdel"]])
# Out:
#                         Model          X Variable(s)  Avg Accuracy  \
# 2                    SVC(C=6)  ['iso_point', 'pdel']        0.9425
# 1     SVC(C=6, kernel='poly')  ['iso_point', 'pdel']        0.9150
# 0   SVC(C=6, kernel='linear')  ['iso_point', 'pdel']        0.8200
# 3  SVC(C=6, kernel='sigmoid')  ['iso_point', 'pdel']        0.7800
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 2        0.070312     0.992674   0.928082  0.959292  0.194598
# 1        0.090967     0.958647   0.917266  0.937500  0.223775
# 0        0.128841     0.911877   0.829268  0.868613  0.236240
# 3        0.116619     0.956044   0.774481  0.855738  0.220356
#
#           Confusion_Matrix
# 2  [[271   2]\n [ 21 106]]
# 1  [[255  11]\n [ 23 111]]
# 0  [[238  23]\n [ 49  90]]
# 3  [[261  12]\n [ 76  51]]

# %% [markdown]
# ### Duos

# %%
ML_compare_variables([SVC(C=6, kernel='rbf')],[["iso_point", "pdel"],
                                                     ["iso_point", "solv_area"],
                                                     ["iso_point", "deldel_G1"],
                                                     ["iso_point", "deldel_G2"],
                                                     ["iso_point", "deldel_G3"],
                                                     ["iso_point", "ogAA_letterCode"],
                                                     ["pdel", "ogAA_letterCode"],
                                                     ["solv_area", "ogAA_letterCode"],
                                                     ["deldel_G3", "ogAA_letterCode"],
                                                     ["deldel_G2", "ogAA_letterCode"],
                                                     ["deldel_G1", "ogAA_letterCode"],
                                                     ["pdel", "deldel_G1"],
                                                     ["pdel", "deldel_G2"],
                                                     ["pdel", "deldel_G3"],
                                                     ["pdel", "solv_area"],
                                                     ["pdel", "iso_point"],
                                                     ["solv_area", "deldel_G1"],
                                                     ["solv_area", "deldel_G2"],
                                                     ["solv_area", "deldel_G3"],
                                                     ["solv_area", "pdel"],
                                                     ["solv_area", "iso_point"]])
# Out:
#        Model                     X Variable(s)  Avg Accuracy  SD of Accuracy  \
# 20  SVC(C=6)        ['solv_area', 'iso_point']        0.9600        0.053852
# 2   SVC(C=6)        ['iso_point', 'deldel_G1']        0.9500        0.054772
# 4   SVC(C=6)        ['iso_point', 'deldel_G3']        0.9425        0.066661
# 3   SVC(C=6)        ['iso_point', 'deldel_G2']        0.9425        0.058683
# 5   SVC(C=6)  ['iso_point', 'ogAA_letterCode']        0.9400        0.062450
# 0   SVC(C=6)             ['iso_point', 'pdel']        0.9400        0.058310
# 15  SVC(C=6)             ['pdel', 'iso_point']        0.9325        0.072068
# 1   SVC(C=6)        ['iso_point', 'solv_area']        0.9325        0.081815
# 6   SVC(C=6)       ['pdel', 'ogAA_letterCode']        0.9050        0.092060
# 14  SVC(C=6)             ['pdel', 'solv_area']        0.8825        0.080273
# 11  SVC(C=6)             ['pdel', 'deldel_G1']        0.8525        0.113990
# 19  SVC(C=6)             ['solv_area', 'pdel']        0.8600        0.086023
# 12  SVC(C=6)             ['pdel', 'deldel_G2']        0.8425        0.089128
# 13  SVC(C=6)             ['pdel', 'deldel_G3']        0.8000        0.122474
# 7   SVC(C=6)  ['solv_area', 'ogAA_letterCode']        0.7275        0.135992
# 10  SVC(C=6)  ['deldel_G1', 'ogAA_letterCode']        0.7425        0.137636
# 9   SVC(C=6)  ['deldel_G2', 'ogAA_letterCode']        0.6850        0.144135
# 8   SVC(C=6)  ['deldel_G3', 'ogAA_letterCode']        0.6550        0.143091
# 18  SVC(C=6)        ['solv_area', 'deldel_G3']        0.5925        0.125275
# 16  SVC(C=6)        ['solv_area', 'deldel_G1']        0.5525        0.170276
# 17  SVC(C=6)        ['solv_area', 'deldel_G2']        0.5350        0.147564
#
#     Sensitivity  Precision  F1-Score   Runtime         Confusion_Matrix
# 20     1.000000   0.942238  0.970260  0.222167  [[261   0]\n [ 16 123]]
# 2      0.996169   0.931900  0.962963  0.215828  [[260   1]\n [ 19 120]]
# 4      0.988848   0.930070  0.958559  0.274651  [[266   3]\n [ 20 111]]
# 3      1.000000   0.920139  0.958409  0.224295  [[265   0]\n [ 23 112]]
# 5      1.000000   0.915493  0.955882  0.243744  [[260   0]\n [ 24 116]]
# 0      0.984556   0.927273  0.955056  0.212270  [[255   4]\n [ 20 121]]
# 15     0.992908   0.918033  0.954003  0.310805  [[280   2]\n [ 25  93]]
# 1      1.000000   0.903915  0.949533  0.239132  [[254   0]\n [ 27 119]]
# 6      0.937743   0.916350  0.926923  0.257447  [[241  16]\n [ 22 121]]
# 14     0.924812   0.901099  0.912801  0.318085  [[246  20]\n [ 27 107]]
# 11     0.907749   0.878571  0.892922  0.269016  [[246  25]\n [ 34  95]]
# 19     0.877863   0.905512  0.891473  0.215581  [[230  32]\n [ 24 114]]
# 12     0.926923   0.845614  0.884404  0.296337  [[241  19]\n [ 44  96]]
# 13     0.891892   0.816254  0.852399  0.313557  [[231  28]\n [ 52  89]]
# 7      0.802281   0.787313  0.794727  0.222674  [[211  52]\n [ 57  80]]
# 10     0.765625   0.820084  0.791919  0.236643  [[196  60]\n [ 43 101]]
# 9      0.712644   0.784810  0.746988  0.213980  [[186  75]\n [ 51  88]]
# 8      0.732283   0.726562  0.729412  0.234897  [[186  68]\n [ 70  76]]
# 18     0.795367   0.651899  0.716522  0.270115  [[206  53]\n [110  31]]
# 16     0.717557   0.641638  0.677477  0.287120  [[188  74]\n [105  33]]
# 17     0.665323   0.615672  0.639535  0.269174  [[165  83]\n [103  49]]

# %% [markdown]
# ### Duos and Trios

# %%
ML_compare_variables([SVC(C=6, kernel='rbf')],[["iso_point", "pdel"],
                                             ["iso_point", "solv_area"],
                                             ["iso_point", "deldel_G1"],
                                             ["iso_point", "deldel_G2"],
                                             ["iso_point", "deldel_G3"],
                                             ["iso_point", "ogAA_letterCode"],
                                             ["pdel", "ogAA_letterCode"],
                                             ["solv_area", "ogAA_letterCode"],
                                             ["deldel_G3", "ogAA_letterCode"],
                                             ["deldel_G2", "ogAA_letterCode"],
                                             ["deldel_G1", "ogAA_letterCode"],
                                             ["pdel", "deldel_G1"],
                                             ["pdel", "deldel_G2"],
                                             ["pdel", "deldel_G3"],
                                             ["pdel", "solv_area"],
                                             ["pdel", "iso_point"],
                                             ["solv_area", "deldel_G1"],
                                             ["solv_area", "deldel_G2"],
                                             ["solv_area", "deldel_G3"],
                                             ["solv_area", "pdel"],
                                             ["solv_area", "iso_point"],
                                             ["pdel", "iso_point", "deldel_G3"],
                                             ["pdel", "iso_point", "solv_area"],
                                             ["pdel", "iso_point", "ogAA_letterCode"],
                                             ["pdel", "iso_point", "deldel_G1"],
                                             ["pdel", "iso_point", "deldel_G2"]])
# Out:
#        Model                             X Variable(s)  Avg Accuracy  \
# 1   SVC(C=6)                ['iso_point', 'solv_area']        0.9675
# 5   SVC(C=6)          ['iso_point', 'ogAA_letterCode']        0.9500
# 15  SVC(C=6)                     ['pdel', 'iso_point']        0.9450
# 2   SVC(C=6)                ['iso_point', 'deldel_G1']        0.9425
# 4   SVC(C=6)                ['iso_point', 'deldel_G3']        0.9400
# 20  SVC(C=6)                ['solv_area', 'iso_point']        0.9325
# 21  SVC(C=6)        ['pdel', 'iso_point', 'deldel_G3']        0.9325
# 3   SVC(C=6)                ['iso_point', 'deldel_G2']        0.9250
# 22  SVC(C=6)        ['pdel', 'iso_point', 'solv_area']        0.9275
# 23  SVC(C=6)  ['pdel', 'iso_point', 'ogAA_letterCode']        0.9225
# 0   SVC(C=6)                     ['iso_point', 'pdel']        0.9225
# 24  SVC(C=6)        ['pdel', 'iso_point', 'deldel_G1']        0.9125
# 25  SVC(C=6)        ['pdel', 'iso_point', 'deldel_G2']        0.9000
# 6   SVC(C=6)               ['pdel', 'ogAA_letterCode']        0.8825
# 19  SVC(C=6)                     ['solv_area', 'pdel']        0.8675
# 11  SVC(C=6)                     ['pdel', 'deldel_G1']        0.8500
# 12  SVC(C=6)                     ['pdel', 'deldel_G2']        0.8550
# 14  SVC(C=6)                     ['pdel', 'solv_area']        0.8475
# 13  SVC(C=6)                     ['pdel', 'deldel_G3']        0.7675
# 10  SVC(C=6)          ['deldel_G1', 'ogAA_letterCode']        0.7600
# 7   SVC(C=6)          ['solv_area', 'ogAA_letterCode']        0.7125
# 9   SVC(C=6)          ['deldel_G2', 'ogAA_letterCode']        0.7000
# 8   SVC(C=6)          ['deldel_G3', 'ogAA_letterCode']        0.6900
# 18  SVC(C=6)                ['solv_area', 'deldel_G3']        0.6150
# 16  SVC(C=6)                ['solv_area', 'deldel_G1']        0.5925
# 17  SVC(C=6)                ['solv_area', 'deldel_G2']        0.6075
#
#     SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 1         0.051901     1.000000   0.952899  0.975881  0.194154
# 5         0.063246     1.000000   0.931741  0.964664  0.202739
# 15        0.073993     0.984733   0.934783  0.959108  0.192271
# 2         0.073782     0.988417   0.927536  0.957009  0.215379
# 4         0.066332     0.991935   0.917910  0.953488  0.203955
# 20        0.075457     0.992278   0.911348  0.950092  0.234512
# 21        0.060776     0.965385   0.933086  0.948960  0.247606
# 3         0.053619     1.000000   0.896907  0.945652  0.221064
# 22        0.074120     0.965251   0.925926  0.945180  0.253465
# 23        0.085110     0.952555   0.935484  0.943942  0.223228
# 0         0.068875     0.992032   0.895683  0.941399  0.207203
# 24        0.084224     0.967213   0.897338  0.930966  0.338176
# 25        0.070711     0.926740   0.926740  0.926740  0.276466
# 6         0.066661     0.956693   0.870968  0.911820  0.205819
# 19        0.078700     0.905303   0.895131  0.900188  0.249592
# 11        0.086603     0.893993   0.893993  0.893993  0.167457
# 12        0.107121     0.909091   0.867925  0.888031  0.211952
# 14        0.107209     0.864341   0.895582  0.879684  0.204253
# 13        0.105801     0.854406   0.802158  0.827458  0.200260
# 10        0.091652     0.792969   0.825203  0.808765  0.202172
# 7         0.112222     0.783784   0.774809  0.779271  0.212716
# 9         0.137840     0.784861   0.749049  0.766537  0.197200
# 8         0.126095     0.765625   0.753846  0.759690  0.217426
# 18        0.108513     0.820312   0.660377  0.731707  0.186954
# 16        0.136725     0.779070   0.654723  0.711504  0.204131
# 17        0.117020     0.709924   0.696629  0.703214  0.211544
#
#            Confusion_Matrix
# 1   [[263   0]\n [ 13 124]]
# 5   [[273   0]\n [ 20 107]]
# 15  [[258   4]\n [ 18 120]]
# 2   [[256   3]\n [ 20 121]]
# 4   [[246   2]\n [ 22 130]]
# 20  [[257   2]\n [ 25 116]]
# 21  [[251   9]\n [ 18 122]]
# 3   [[261   0]\n [ 30 109]]
# 22  [[250   9]\n [ 20 121]]
# 23  [[261  13]\n [ 18 108]]
# 0   [[249   2]\n [ 29 120]]
# 24  [[236   8]\n [ 27 129]]
# 25  [[253  20]\n [ 20 107]]
# 6   [[243  11]\n [ 36 110]]
# 19  [[239  25]\n [ 28 108]]
# 11  [[253  30]\n [ 30  87]]
# 12  [[230  23]\n [ 35 112]]
# 14  [[223  35]\n [ 26 116]]
# 13  [[223  38]\n [ 55  84]]
# 10  [[203  53]\n [ 43 101]]
# 7   [[203  56]\n [ 59  82]]
# 9   [[197  54]\n [ 66  83]]
# 8   [[196  60]\n [ 64  80]]
# 18  [[210  46]\n [108  36]]
# 16  [[201  57]\n [106  36]]
# 17  [[186  76]\n [ 81  57]]

# %% [markdown]
# # Everything
#
# Using the function made to compare various models and variable combinations as covariates, we were able to easily see the best performing models (and the variables with which were used as covariates). Not surprisingly, KNN and SVC models found their way to the top of the ranked table list.____ need the trees please____

# %% [markdown]
# ### duos

# %%
ML_compare_variables([SVC(C=1, kernel='rbf'),LinearDiscriminantAnalysis(), neighbors.KNeighborsClassifier(n_neighbors = 3), ],[["iso_point", "pdel"],
                                                     ["iso_point", "solv_area"],
                                                     ["iso_point", "deldel_G1"],
                                                     ["iso_point", "deldel_G2"],
                                                     ["iso_point", "deldel_G3"],
                                                     ["iso_point", "ogAA_letterCode"],
                                                     ["pdel", "ogAA_letterCode"],
                                                     ["solv_area", "ogAA_letterCode"],
                                                     ["deldel_G3", "ogAA_letterCode"],
                                                     ["deldel_G2", "ogAA_letterCode"],
                                                     ["deldel_G1", "ogAA_letterCode"],
                                                     ["pdel", "deldel_G1"],
                                                     ["pdel", "deldel_G2"],
                                                     ["pdel", "deldel_G3"],
                                                     ["pdel", "solv_area"],
                                                     ["pdel", "iso_point"],
                                                     ["solv_area", "deldel_G1"],
                                                     ["solv_area", "deldel_G2"],
                                                     ["solv_area", "deldel_G3"],
                                                     ["solv_area", "pdel"],
                                                     ["solv_area", "iso_point"]])
# Out:
#                                   Model                     X Variable(s)  \
# 47  KNeighborsClassifier(n_neighbors=3)  ['iso_point', 'ogAA_letterCode']
# 1                              SVC(C=1)        ['iso_point', 'solv_area']
# 3                              SVC(C=1)        ['iso_point', 'deldel_G2']
# 4                              SVC(C=1)        ['iso_point', 'deldel_G3']
# 42  KNeighborsClassifier(n_neighbors=3)             ['iso_point', 'pdel']
# 0                              SVC(C=1)             ['iso_point', 'pdel']
# 20                             SVC(C=1)        ['solv_area', 'iso_point']
# 46  KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'deldel_G3']
# 2                              SVC(C=1)        ['iso_point', 'deldel_G1']
# 57  KNeighborsClassifier(n_neighbors=3)             ['pdel', 'iso_point']
# 44  KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'deldel_G1']
# 62  KNeighborsClassifier(n_neighbors=3)        ['solv_area', 'iso_point']
# 15                             SVC(C=1)             ['pdel', 'iso_point']
# 43  KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'solv_area']
# 5                              SVC(C=1)  ['iso_point', 'ogAA_letterCode']
# 45  KNeighborsClassifier(n_neighbors=3)        ['iso_point', 'deldel_G2']
# 6                              SVC(C=1)       ['pdel', 'ogAA_letterCode']
# 14                             SVC(C=1)             ['pdel', 'solv_area']
# 19                             SVC(C=1)             ['solv_area', 'pdel']
# 55  KNeighborsClassifier(n_neighbors=3)             ['pdel', 'deldel_G3']
# 48  KNeighborsClassifier(n_neighbors=3)       ['pdel', 'ogAA_letterCode']
# 40         LinearDiscriminantAnalysis()             ['solv_area', 'pdel']
# 53  KNeighborsClassifier(n_neighbors=3)             ['pdel', 'deldel_G1']
# 35         LinearDiscriminantAnalysis()             ['pdel', 'solv_area']
# 56  KNeighborsClassifier(n_neighbors=3)             ['pdel', 'solv_area']
# 11                             SVC(C=1)             ['pdel', 'deldel_G1']
# 12                             SVC(C=1)             ['pdel', 'deldel_G2']
# 34         LinearDiscriminantAnalysis()             ['pdel', 'deldel_G3']
# 32         LinearDiscriminantAnalysis()             ['pdel', 'deldel_G1']
# 33         LinearDiscriminantAnalysis()             ['pdel', 'deldel_G2']
# 61  KNeighborsClassifier(n_neighbors=3)             ['solv_area', 'pdel']
# 27         LinearDiscriminantAnalysis()       ['pdel', 'ogAA_letterCode']
# 13                             SVC(C=1)             ['pdel', 'deldel_G3']
# 21         LinearDiscriminantAnalysis()             ['iso_point', 'pdel']
# 36         LinearDiscriminantAnalysis()             ['pdel', 'iso_point']
# 54  KNeighborsClassifier(n_neighbors=3)             ['pdel', 'deldel_G2']
# 24         LinearDiscriminantAnalysis()        ['iso_point', 'deldel_G2']
# 9                              SVC(C=1)  ['deldel_G2', 'ogAA_letterCode']
# 49  KNeighborsClassifier(n_neighbors=3)  ['solv_area', 'ogAA_letterCode']
# 7                              SVC(C=1)  ['solv_area', 'ogAA_letterCode']
# 52  KNeighborsClassifier(n_neighbors=3)  ['deldel_G1', 'ogAA_letterCode']
# 25         LinearDiscriminantAnalysis()        ['iso_point', 'deldel_G3']
# 18                             SVC(C=1)        ['solv_area', 'deldel_G3']
# 10                             SVC(C=1)  ['deldel_G1', 'ogAA_letterCode']
# 8                              SVC(C=1)  ['deldel_G3', 'ogAA_letterCode']
# 23         LinearDiscriminantAnalysis()        ['iso_point', 'deldel_G1']
# 50  KNeighborsClassifier(n_neighbors=3)  ['deldel_G3', 'ogAA_letterCode']
# 41         LinearDiscriminantAnalysis()        ['solv_area', 'iso_point']
# 16                             SVC(C=1)        ['solv_area', 'deldel_G1']
# 30         LinearDiscriminantAnalysis()  ['deldel_G2', 'ogAA_letterCode']
# 59  KNeighborsClassifier(n_neighbors=3)        ['solv_area', 'deldel_G2']
# 60  KNeighborsClassifier(n_neighbors=3)        ['solv_area', 'deldel_G3']
# 38         LinearDiscriminantAnalysis()        ['solv_area', 'deldel_G2']
# 22         LinearDiscriminantAnalysis()        ['iso_point', 'solv_area']
# 26         LinearDiscriminantAnalysis()  ['iso_point', 'ogAA_letterCode']
# 31         LinearDiscriminantAnalysis()  ['deldel_G1', 'ogAA_letterCode']
# 39         LinearDiscriminantAnalysis()        ['solv_area', 'deldel_G3']
# 29         LinearDiscriminantAnalysis()  ['deldel_G3', 'ogAA_letterCode']
# 51  KNeighborsClassifier(n_neighbors=3)  ['deldel_G2', 'ogAA_letterCode']
# 28         LinearDiscriminantAnalysis()  ['solv_area', 'ogAA_letterCode']
# 17                             SVC(C=1)        ['solv_area', 'deldel_G2']
# 37         LinearDiscriminantAnalysis()        ['solv_area', 'deldel_G1']
# 58  KNeighborsClassifier(n_neighbors=3)        ['solv_area', 'deldel_G1']
#
#     Avg Accuracy  SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 47        0.9750        0.048734     1.000000   0.964413  0.981884  0.237967
# 1         0.9600        0.048990     1.000000   0.943860  0.971119  0.188360
# 3         0.9600        0.048990     1.000000   0.942652  0.970480  0.182837
# 4         0.9550        0.054544     0.985294   0.950355  0.967509  0.167048
# 42        0.9550        0.058949     1.000000   0.935484  0.966667  0.259170
# 0         0.9500        0.059161     1.000000   0.928315  0.962825  0.168524
# 20        0.9450        0.063048     1.000000   0.921708  0.959259  0.248481
# 46        0.9450        0.063048     1.000000   0.921708  0.959259  0.232985
# 2         0.9450        0.054544     0.980989   0.938182  0.959108  0.198216
# 57        0.9425        0.077096     1.000000   0.919298  0.957952  0.234980
# 44        0.9400        0.062450     1.000000   0.916084  0.956204  0.242722
# 62        0.9375        0.091344     1.000000   0.912892  0.954463  0.258544
# 15        0.9350        0.057228     1.000000   0.908451  0.952030  0.207426
# 43        0.9275        0.080584     1.000000   0.900000  0.947368  0.263282
# 5         0.9175        0.077096     1.000000   0.885813  0.939450  0.165431
# 45        0.9150        0.069101     1.000000   0.885135  0.939068  0.226678
# 6         0.8875        0.078062     0.918605   0.908046  0.913295  0.190756
# 14        0.8750        0.104283     0.920755   0.893773  0.907063  0.210933
# 19        0.8775        0.082120     0.915709   0.898496  0.907021  0.217642
# 55        0.8600        0.099499     0.920455   0.874101  0.896679  0.279128
# 48        0.8625        0.099216     0.914729   0.877323  0.895636  0.252313
# 40        0.8600        0.101980     0.918288   0.870849  0.893939  0.211594
# 53        0.8525        0.086566     0.908745   0.872263  0.890130  0.275199
# 35        0.8525        0.113990     0.916335   0.858209  0.886320  0.219266
# 56        0.8475        0.089408     0.883019   0.886364  0.884688  0.301110
# 11        0.8400        0.091652     0.892720   0.866171  0.879245  0.192326
# 12        0.8325        0.125275     0.939516   0.817544  0.874296  0.193625
# 34        0.8325        0.110425     0.888462   0.858736  0.873346  0.176295
# 32        0.8325        0.117020     0.892430   0.848485  0.869903  0.211860
# 33        0.8275        0.097436     0.875502   0.851562  0.863366  0.186247
# 61        0.8275        0.102439     0.872000   0.854902  0.863366  0.220881
# 27        0.8250        0.082916     0.862205   0.862205  0.862205  0.187969
# 13        0.8125        0.100468     0.886719   0.831502  0.858223  0.179149
# 21        0.7900        0.146287     0.903101   0.797945  0.847273  0.206275
# 36        0.7825        0.122245     0.914062   0.782609  0.843243  0.188422
# 54        0.7700        0.136382     0.793233   0.850806  0.821012  0.249961
# 24        0.6875        0.128817     0.963768   0.698163  0.809741  0.220519
# 9         0.6875        0.132641     0.988722   0.683117  0.807988  0.180308
# 49        0.7225        0.103652     0.839506   0.739130  0.786127  0.191252
# 7         0.6650        0.123592     0.923954   0.680672  0.783871  0.194836
# 52        0.7150        0.145860     0.769811   0.793774  0.781609  0.267378
# 25        0.6425        0.157936     0.968872   0.648438  0.776911  0.200630
# 18        0.6400        0.104403     0.929104   0.665775  0.775701  0.216385
# 10        0.6500        0.146629     0.927203   0.666667  0.775641  0.169862
# 8         0.6425        0.118084     0.930502   0.658470  0.771200  0.167542
# 23        0.6200        0.116619     0.953488   0.637306  0.763975  0.192753
# 50        0.6850        0.125599     0.767176   0.755639  0.761364  0.235268
# 41        0.6225        0.129398     0.936255   0.635135  0.756844  0.264693
# 16        0.6125        0.100468     0.933852   0.634921  0.755906  0.228840
# 30        0.6150        0.113027     0.908397   0.646739  0.755556  0.196174
# 59        0.6625        0.151141     0.802372   0.704861  0.750462  0.241683
# 60        0.6475        0.158094     0.753571   0.745583  0.749556  0.241042
# 38        0.5925        0.110425     0.893536   0.635135  0.742496  0.215430
# 22        0.5975        0.125474     0.891473   0.633609  0.740741  0.209192
# 26        0.6025        0.133206     0.844697   0.653959  0.737190  0.201838
# 31        0.5850        0.096307     0.874046   0.632597  0.733974  0.226161
# 39        0.5975        0.129398     0.850575   0.645349  0.733884  0.215767
# 29        0.5900        0.137477     0.893281   0.622590  0.733766  0.195716
# 51        0.6425        0.144720     0.763566   0.706093  0.733706  0.242654
# 28        0.5850        0.127574     0.853282   0.633238  0.726974  0.195045
# 17        0.5925        0.138542     0.815789   0.655589  0.726968  0.247728
# 37        0.5550        0.144827     0.851562   0.608939  0.710098  0.196405
# 58        0.5700        0.153623     0.740310   0.645270  0.689531  0.228487
#
#            Confusion_Matrix
# 47  [[271   0]\n [ 10 119]]
# 1   [[269   0]\n [ 16 115]]
# 3   [[263   0]\n [ 16 121]]
# 4   [[268   4]\n [ 14 114]]
# 42  [[261   0]\n [ 18 121]]
# 0   [[259   0]\n [ 20 121]]
# 20  [[259   0]\n [ 22 119]]
# 46  [[259   0]\n [ 22 119]]
# 2   [[258   5]\n [ 17 120]]
# 57  [[262   0]\n [ 23 115]]
# 44  [[262   0]\n [ 24 114]]
# 62  [[262   0]\n [ 25 113]]
# 15  [[258   0]\n [ 26 116]]
# 43  [[261   0]\n [ 29 110]]
# 5   [[256   0]\n [ 33 111]]
# 45  [[262   0]\n [ 34 104]]
# 6   [[237  21]\n [ 24 118]]
# 14  [[244  21]\n [ 29 106]]
# 19  [[239  22]\n [ 27 112]]
# 55  [[243  21]\n [ 35 101]]
# 48  [[236  22]\n [ 33 109]]
# 40  [[236  21]\n [ 35 108]]
# 53  [[239  24]\n [ 35 102]]
# 35  [[230  21]\n [ 38 111]]
# 56  [[234  31]\n [ 30 105]]
# 11  [[233  28]\n [ 36 103]]
# 12  [[233  15]\n [ 52 100]]
# 34  [[231  29]\n [ 38 102]]
# 32  [[224  27]\n [ 40 109]]
# 33  [[218  31]\n [ 38 113]]
# 61  [[218  32]\n [ 37 113]]
# 27  [[219  35]\n [ 35 111]]
# 13  [[227  29]\n [ 46  98]]
# 21  [[233  25]\n [ 59  83]]
# 36  [[234  22]\n [ 65  79]]
# 54  [[211  55]\n [ 37  97]]
# 24  [[266  10]\n [115   9]]
# 9   [[263   3]\n [122  12]]
# 49  [[204  39]\n [ 72  85]]
# 7   [[243  20]\n [114  23]]
# 52  [[204  61]\n [ 53  82]]
# 25  [[249   8]\n [135   8]]
# 18  [[249  19]\n [125   7]]
# 10  [[242  19]\n [121  18]]
# 8   [[241  18]\n [125  16]]
# 23  [[246  12]\n [140   2]]
# 50  [[201  61]\n [ 65  73]]
# 41  [[235  16]\n [135  14]]
# 16  [[240  17]\n [138   5]]
# 30  [[238  24]\n [130   8]]
# 59  [[203  50]\n [ 85  62]]
# 60  [[211  69]\n [ 72  48]]
# 38  [[235  28]\n [135   2]]
# 22  [[230  28]\n [133   9]]
# 26  [[223  41]\n [118  18]]
# 31  [[229  33]\n [133   5]]
# 39  [[222  39]\n [122  17]]
# 29  [[226  27]\n [137  10]]
# 51  [[197  61]\n [ 82  60]]
# 28  [[221  38]\n [128  13]]
# 17  [[217  49]\n [114  20]]
# 37  [[218  38]\n [140   4]]
# 58  [[191  67]\n [105  37]]

# %% [markdown]
# ### trios

# %%
ML_compare_variables([SVC(C=1, kernel='rbf'),LinearDiscriminantAnalysis(), neighbors.KNeighborsClassifier(n_neighbors = 3)],[["pdel", "iso_point", "deldel_G3"],
                                                                        ["pdel", "iso_point", "solv_area"],
                                                                        ["pdel", "iso_point", "ogAA_letterCode"],
                                                                        ["pdel", "iso_point", "deldel_G1"],
                                                                        ["pdel", "iso_point", "deldel_G2"]])
# Out:
#                                   Model  \
# 12  KNeighborsClassifier(n_neighbors=3)
# 3                              SVC(C=1)
# 14  KNeighborsClassifier(n_neighbors=3)
# 10  KNeighborsClassifier(n_neighbors=3)
# 0                              SVC(C=1)
# 13  KNeighborsClassifier(n_neighbors=3)
# 1                              SVC(C=1)
# 2                              SVC(C=1)
# 4                              SVC(C=1)
# 11  KNeighborsClassifier(n_neighbors=3)
# 7          LinearDiscriminantAnalysis()
# 6          LinearDiscriminantAnalysis()
# 9          LinearDiscriminantAnalysis()
# 5          LinearDiscriminantAnalysis()
# 8          LinearDiscriminantAnalysis()
#
#                                X Variable(s)  Avg Accuracy  SD of Accuracy  \
# 12  ['pdel', 'iso_point', 'ogAA_letterCode']        0.9500        0.077460
# 3         ['pdel', 'iso_point', 'deldel_G1']        0.9450        0.066895
# 14        ['pdel', 'iso_point', 'deldel_G2']        0.9425        0.097179
# 10        ['pdel', 'iso_point', 'deldel_G3']        0.9375        0.091344
# 0         ['pdel', 'iso_point', 'deldel_G3']        0.9250        0.062249
# 13        ['pdel', 'iso_point', 'deldel_G1']        0.9200        0.071414
# 1         ['pdel', 'iso_point', 'solv_area']        0.9200        0.097980
# 2   ['pdel', 'iso_point', 'ogAA_letterCode']        0.9075        0.075457
# 4         ['pdel', 'iso_point', 'deldel_G2']        0.9050        0.077298
# 11        ['pdel', 'iso_point', 'solv_area']        0.8875        0.089965
# 7   ['pdel', 'iso_point', 'ogAA_letterCode']        0.8375        0.096663
# 6         ['pdel', 'iso_point', 'solv_area']        0.8175        0.153114
# 9         ['pdel', 'iso_point', 'deldel_G2']        0.8200        0.140000
# 5         ['pdel', 'iso_point', 'deldel_G3']        0.8075        0.117020
# 8         ['pdel', 'iso_point', 'deldel_G1']        0.8075        0.138542
#
#     Sensitivity  Precision  F1-Score   Runtime         Confusion_Matrix
# 12     1.000000   0.925094  0.961089  0.310507  [[247   0]\n [ 20 133]]
# 3      1.000000   0.921429  0.959108  0.264918  [[258   0]\n [ 22 120]]
# 14     1.000000   0.916968  0.956685  0.305992  [[254   0]\n [ 23 123]]
# 10     1.000000   0.914384  0.955277  0.303421  [[267   0]\n [ 25 108]]
# 0      0.974910   0.922034  0.947735  0.261526  [[272   7]\n [ 23  98]]
# 13     1.000000   0.887324  0.940299  0.300659  [[252   0]\n [ 32 116]]
# 1      0.991667   0.888060  0.937008  0.243858  [[238   2]\n [ 30 130]]
# 2      0.992453   0.882550  0.934281  0.272810  [[263   2]\n [ 35 100]]
# 4      0.984733   0.883562  0.931408  0.256035  [[258   4]\n [ 34 104]]
# 11     0.995868   0.845614  0.914611  0.303483  [[241   1]\n [ 44 114]]
# 7      0.898833   0.855556  0.876660  0.261217  [[231  26]\n [ 39 104]]
# 6      0.929368   0.822368  0.872600  0.260874  [[250  19]\n [ 54  77]]
# 9      0.931559   0.819398  0.871886  0.259219  [[245  18]\n [ 54  83]]
# 5      0.893130   0.826855  0.858716  0.278908  [[234  28]\n [ 49  89]]
# 8      0.925620   0.791519  0.853333  0.271723  [[224  18]\n [ 59  99]]

# %% [markdown]
# ### duos and trios

# %%
ML_compare_variables([SVC(C=1, kernel='rbf'),LinearDiscriminantAnalysis(), neighbors.KNeighborsClassifier(n_neighbors = 3)],[["iso_point", "pdel"],
                                                     ["iso_point", "solv_area"],
                                                     ["iso_point", "deldel_G1"],
                                                     ["iso_point", "deldel_G2"],
                                                     ["iso_point", "deldel_G3"],
                                                     ["iso_point", "ogAA_letterCode"],
                                                     ["pdel", "ogAA_letterCode"],
                                                     ["solv_area", "ogAA_letterCode"],
                                                     ["deldel_G3", "ogAA_letterCode"],
                                                     ["deldel_G2", "ogAA_letterCode"],
                                                     ["deldel_G1", "ogAA_letterCode"],
                                                     ["pdel", "deldel_G1"],
                                                     ["pdel", "deldel_G2"],
                                                     ["pdel", "deldel_G3"],
                                                     ["pdel", "solv_area"],
                                                     ["pdel", "iso_point"],
                                                     ["solv_area", "deldel_G1"],
                                                     ["solv_area", "deldel_G2"],
                                                     ["solv_area", "deldel_G3"],
                                                     ["solv_area", "pdel"],
                                                     ["solv_area", "iso_point"],                                                   
                                                     ["iso_point", "pdel", "deldel_G3"],
                                                     ["iso_point", "pdel", "solv_area"],
                                                     ["iso_point", "pdel", "ogAA_letterCode"],
                                                     ["iso_point", "pdel", "deldel_G1"],
                                                     ["iso_point", "pdel", "deldel_G2"]])
# Out:
#                                   Model  \
# 15                             SVC(C=1)
# 0                              SVC(C=1)
# 72  KNeighborsClassifier(n_neighbors=3)
# 24                             SVC(C=1)
# 3                              SVC(C=1)
# 22                             SVC(C=1)
# 76  KNeighborsClassifier(n_neighbors=3)
# 75  KNeighborsClassifier(n_neighbors=3)
# 54  KNeighborsClassifier(n_neighbors=3)
# 1                              SVC(C=1)
# 56  KNeighborsClassifier(n_neighbors=3)
# 57  KNeighborsClassifier(n_neighbors=3)
# 52  KNeighborsClassifier(n_neighbors=3)
# 73  KNeighborsClassifier(n_neighbors=3)
# 20                             SVC(C=1)
# 2                              SVC(C=1)
# 53  KNeighborsClassifier(n_neighbors=3)
# 25                             SVC(C=1)
# 77  KNeighborsClassifier(n_neighbors=3)
# 67  KNeighborsClassifier(n_neighbors=3)
# 74  KNeighborsClassifier(n_neighbors=3)
# 23                             SVC(C=1)
# 55  KNeighborsClassifier(n_neighbors=3)
# 21                             SVC(C=1)
# 5                              SVC(C=1)
# 4                              SVC(C=1)
# 39         LinearDiscriminantAnalysis()
# 14                             SVC(C=1)
# 45         LinearDiscriminantAnalysis()
# 19                             SVC(C=1)
# 6                              SVC(C=1)
# 12                             SVC(C=1)
# 38         LinearDiscriminantAnalysis()
# 32         LinearDiscriminantAnalysis()
# 26         LinearDiscriminantAnalysis()
# 37         LinearDiscriminantAnalysis()
# 63  KNeighborsClassifier(n_neighbors=3)
# 58  KNeighborsClassifier(n_neighbors=3)
# 40         LinearDiscriminantAnalysis()
# 11                             SVC(C=1)
# 41         LinearDiscriminantAnalysis()
# 51         LinearDiscriminantAnalysis()
# 13                             SVC(C=1)
# 48         LinearDiscriminantAnalysis()
# 64  KNeighborsClassifier(n_neighbors=3)
# 71  KNeighborsClassifier(n_neighbors=3)
# 65  KNeighborsClassifier(n_neighbors=3)
# 66  KNeighborsClassifier(n_neighbors=3)
# 50         LinearDiscriminantAnalysis()
# 49         LinearDiscriminantAnalysis()
# 47         LinearDiscriminantAnalysis()
# 7                              SVC(C=1)
# 9                              SVC(C=1)
# 62  KNeighborsClassifier(n_neighbors=3)
# 28         LinearDiscriminantAnalysis()
# 59  KNeighborsClassifier(n_neighbors=3)
# 61  KNeighborsClassifier(n_neighbors=3)
# 16                             SVC(C=1)
# 29         LinearDiscriminantAnalysis()
# 30         LinearDiscriminantAnalysis()
# 69  KNeighborsClassifier(n_neighbors=3)
# 60  KNeighborsClassifier(n_neighbors=3)
# 10                             SVC(C=1)
# 33         LinearDiscriminantAnalysis()
# 8                              SVC(C=1)
# 27         LinearDiscriminantAnalysis()
# 34         LinearDiscriminantAnalysis()
# 18                             SVC(C=1)
# 35         LinearDiscriminantAnalysis()
# 31         LinearDiscriminantAnalysis()
# 70  KNeighborsClassifier(n_neighbors=3)
# 44         LinearDiscriminantAnalysis()
# 17                             SVC(C=1)
# 42         LinearDiscriminantAnalysis()
# 36         LinearDiscriminantAnalysis()
# 46         LinearDiscriminantAnalysis()
# 43         LinearDiscriminantAnalysis()
# 68  KNeighborsClassifier(n_neighbors=3)
#
#                                X Variable(s)  Avg Accuracy  SD of Accuracy  \
# 15                     ['pdel', 'iso_point']        0.9625        0.048412
# 0                      ['iso_point', 'pdel']        0.9575        0.049434
# 72                ['solv_area', 'iso_point']        0.9500        0.059161
# 24        ['iso_point', 'pdel', 'deldel_G1']        0.9525        0.063196
# 3                 ['iso_point', 'deldel_G2']        0.9475        0.059108
# 22        ['iso_point', 'pdel', 'solv_area']        0.9500        0.054772
# 76        ['iso_point', 'pdel', 'deldel_G1']        0.9450        0.063048
# 75  ['iso_point', 'pdel', 'ogAA_letterCode']        0.9425        0.080273
# 54                ['iso_point', 'deldel_G1']        0.9400        0.076811
# 1                 ['iso_point', 'solv_area']        0.9425        0.058683
# 56                ['iso_point', 'deldel_G3']        0.9400        0.062450
# 57          ['iso_point', 'ogAA_letterCode']        0.9400        0.083066
# 52                     ['iso_point', 'pdel']        0.9450        0.063048
# 73        ['iso_point', 'pdel', 'deldel_G3']        0.9375        0.069597
# 20                ['solv_area', 'iso_point']        0.9400        0.066332
# 2                 ['iso_point', 'deldel_G1']        0.9350        0.065383
# 53                ['iso_point', 'solv_area']        0.9275        0.086566
# 25        ['iso_point', 'pdel', 'deldel_G2']        0.9300        0.107703
# 77        ['iso_point', 'pdel', 'deldel_G2']        0.9275        0.067035
# 67                     ['pdel', 'iso_point']        0.9275        0.080584
# 74        ['iso_point', 'pdel', 'solv_area']        0.9300        0.081240
# 23  ['iso_point', 'pdel', 'ogAA_letterCode']        0.9175        0.086277
# 55                ['iso_point', 'deldel_G2']        0.9225        0.072414
# 21        ['iso_point', 'pdel', 'deldel_G3']        0.9150        0.079215
# 5           ['iso_point', 'ogAA_letterCode']        0.9000        0.070711
# 4                 ['iso_point', 'deldel_G3']        0.9025        0.085110
# 39                     ['pdel', 'deldel_G3']        0.8900        0.080000
# 14                     ['pdel', 'solv_area']        0.8900        0.086023
# 45                     ['solv_area', 'pdel']        0.8775        0.101211
# 19                     ['solv_area', 'pdel']        0.8675        0.072068
# 6                ['pdel', 'ogAA_letterCode']        0.8625        0.115515
# 12                     ['pdel', 'deldel_G2']        0.8550        0.107121
# 38                     ['pdel', 'deldel_G2']        0.8500        0.092195
# 32               ['pdel', 'ogAA_letterCode']        0.8475        0.107209
# 26                     ['iso_point', 'pdel']        0.8350        0.127574
# 37                     ['pdel', 'deldel_G1']        0.8400        0.128062
# 63                     ['pdel', 'deldel_G1']        0.8425        0.104612
# 58               ['pdel', 'ogAA_letterCode']        0.8425        0.102195
# 40                     ['pdel', 'solv_area']        0.8425        0.132075
# 11                     ['pdel', 'deldel_G1']        0.8275        0.111775
# 41                     ['pdel', 'iso_point']        0.8175        0.120182
# 51        ['iso_point', 'pdel', 'deldel_G2']        0.8075        0.114864
# 13                     ['pdel', 'deldel_G3']        0.8125        0.087142
# 48        ['iso_point', 'pdel', 'solv_area']        0.8025        0.142281
# 64                     ['pdel', 'deldel_G2']        0.8150        0.098869
# 71                     ['solv_area', 'pdel']        0.8100        0.088882
# 65                     ['pdel', 'deldel_G3']        0.8125        0.102926
# 66                     ['pdel', 'solv_area']        0.8100        0.101980
# 50        ['iso_point', 'pdel', 'deldel_G1']        0.8025        0.108369
# 49  ['iso_point', 'pdel', 'ogAA_letterCode']        0.7975        0.108369
# 47        ['iso_point', 'pdel', 'deldel_G3']        0.7625        0.129783
# 7           ['solv_area', 'ogAA_letterCode']        0.6975        0.147458
# 9           ['deldel_G2', 'ogAA_letterCode']        0.6850        0.138834
# 62          ['deldel_G1', 'ogAA_letterCode']        0.7325        0.140334
# 28                ['iso_point', 'deldel_G1']        0.6600        0.137477
# 59          ['solv_area', 'ogAA_letterCode']        0.7000        0.122474
# 61          ['deldel_G2', 'ogAA_letterCode']        0.7050        0.156445
# 16                ['solv_area', 'deldel_G1']        0.6350        0.108513
# 29                ['iso_point', 'deldel_G2']        0.6275        0.135992
# 30                ['iso_point', 'deldel_G3']        0.6350        0.110793
# 69                ['solv_area', 'deldel_G2']        0.6800        0.124900
# 60          ['deldel_G3', 'ogAA_letterCode']        0.6800        0.141774
# 10          ['deldel_G1', 'ogAA_letterCode']        0.6200        0.136382
# 33          ['solv_area', 'ogAA_letterCode']        0.6250        0.135554
# 8           ['deldel_G3', 'ogAA_letterCode']        0.6075        0.121218
# 27                ['iso_point', 'solv_area']        0.6025        0.117234
# 34          ['deldel_G3', 'ogAA_letterCode']        0.6100        0.154596
# 18                ['solv_area', 'deldel_G3']        0.5950        0.111692
# 35          ['deldel_G2', 'ogAA_letterCode']        0.6000        0.144914
# 31          ['iso_point', 'ogAA_letterCode']        0.5900        0.142829
# 70                ['solv_area', 'deldel_G3']        0.6325        0.157142
# 44                ['solv_area', 'deldel_G3']        0.5825        0.156345
# 17                ['solv_area', 'deldel_G2']        0.5925        0.119138
# 42                ['solv_area', 'deldel_G1']        0.5725        0.128428
# 36          ['deldel_G1', 'ogAA_letterCode']        0.5750        0.123996
# 46                ['solv_area', 'iso_point']        0.5700        0.132665
# 43                ['solv_area', 'deldel_G2']        0.5450        0.137750
# 68                ['solv_area', 'deldel_G1']        0.5750        0.119896
#
#     Sensitivity  Precision  F1-Score   Runtime         Confusion_Matrix
# 15     1.000000   0.947368  0.972973  0.235594  [[270   0]\n [ 15 115]]
# 0      1.000000   0.936090  0.966990  0.255743  [[249   0]\n [ 17 134]]
# 72     1.000000   0.931973  0.964789  0.314210  [[274   0]\n [ 20 106]]
# 24     1.000000   0.930657  0.964083  0.259002  [[255   0]\n [ 19 126]]
# 3      1.000000   0.927835  0.962567  0.266254  [[270   0]\n [ 21 109]]
# 22     0.996063   0.930147  0.961977  0.251071  [[253   1]\n [ 19 127]]
# 76     1.000000   0.922261  0.959559  0.302013  [[261   0]\n [ 22 117]]
# 75     1.000000   0.919861  0.958258  0.309056  [[264   0]\n [ 23 113]]
# 54     1.000000   0.917526  0.956989  0.327724  [[267   0]\n [ 24 109]]
# 1      1.000000   0.917266  0.956848  0.247656  [[255   0]\n [ 23 122]]
# 56     1.000000   0.916955  0.956679  0.321768  [[265   0]\n [ 24 111]]
# 57     1.000000   0.916084  0.956204  0.321874  [[262   0]\n [ 24 114]]
# 52     1.000000   0.916031  0.956175  0.359547  [[240   0]\n [ 22 138]]
# 73     1.000000   0.911972  0.953959  0.345209  [[259   0]\n [ 25 116]]
# 20     1.000000   0.911439  0.953668  0.265919  [[247   0]\n [ 24 129]]
# 2      0.977099   0.927536  0.951673  0.231576  [[256   6]\n [ 20 118]]
# 53     1.000000   0.904290  0.949740  0.339447  [[274   0]\n [ 29  97]]
# 25     0.996078   0.903915  0.947761  0.252048  [[254   1]\n [ 27 118]]
# 77     0.996139   0.902098  0.946789  0.340274  [[258   1]\n [ 28 113]]
# 67     1.000000   0.897163  0.945794  0.331864  [[253   0]\n [ 29 118]]
# 74     1.000000   0.896679  0.945525  0.321945  [[243   0]\n [ 28 129]]
# 23     0.996324   0.894389  0.942609  0.247078  [[271   1]\n [ 32  96]]
# 55     1.000000   0.889680  0.941620  0.341728  [[250   0]\n [ 31 119]]
# 21     0.965909   0.910714  0.937500  0.246021  [[255   9]\n [ 25 111]]
# 5      1.000000   0.866221  0.928315  0.268084  [[259   0]\n [ 40 101]]
# 4      0.983539   0.872263  0.924565  0.257105  [[239   4]\n [ 35 122]]
# 39     0.929630   0.909420  0.919414  0.305740  [[251  19]\n [ 25 105]]
# 14     0.937500   0.885827  0.910931  0.269872  [[225  15]\n [ 29 131]]
# 45     0.881481   0.933333  0.906667  0.328135  [[238  32]\n [ 17 113]]
# 19     0.893939   0.904215  0.899048  0.250449  [[236  28]\n [ 25 111]]
# 6      0.924901   0.866667  0.894837  0.278464  [[234  19]\n [ 36 111]]
# 12     0.922481   0.862319  0.891386  0.270268  [[238  20]\n [ 38 104]]
# 38     0.890152   0.883459  0.886792  0.270831  [[235  29]\n [ 31 105]]
# 32     0.865672   0.902724  0.883810  0.274549  [[232  36]\n [ 25 107]]
# 26     0.946970   0.827815  0.883392  0.274672  [[250  14]\n [ 52  84]]
# 37     0.866667   0.893130  0.879699  0.308062  [[234  36]\n [ 28 102]]
# 63     0.905512   0.855019  0.879541  0.383668  [[230  24]\n [ 39 107]]
# 58     0.905138   0.854478  0.879079  0.356082  [[229  24]\n [ 39 108]]
# 40     0.876923   0.880309  0.878613  0.270351  [[228  32]\n [ 31 109]]
# 11     0.914062   0.832740  0.871508  0.236207  [[234  22]\n [ 47  97]]
# 41     0.934866   0.813333  0.869875  0.293959  [[244  17]\n [ 56  83]]
# 51     0.895911   0.831034  0.862254  0.298146  [[241  28]\n [ 49  82]]
# 13     0.874525   0.845588  0.859813  0.258727  [[230  33]\n [ 42  95]]
# 48     0.919540   0.805369  0.858676  0.293095  [[240  21]\n [ 58  81]]
# 64     0.864341   0.851145  0.857692  0.363382  [[223  35]\n [ 39 103]]
# 71     0.845018   0.870722  0.857678  0.329064  [[229  42]\n [ 34  95]]
# 65     0.870079   0.840304  0.854932  0.349074  [[221  33]\n [ 42 104]]
# 66     0.863281   0.843511  0.853282  0.325237  [[221  35]\n [ 41 103]]
# 50     0.904762   0.805654  0.852336  0.355625  [[228  24]\n [ 55  93]]
# 49     0.832117   0.866920  0.849162  0.358486  [[228  46]\n [ 35  91]]
# 47     0.881041   0.790000  0.833040  0.315209  [[237  32]\n [ 63  68]]
# 7      0.943609   0.703081  0.805778  0.246656  [[251  15]\n [106  28]]
# 9      0.962687   0.689840  0.803738  0.266544  [[258  10]\n [116  16]]
# 62     0.801556   0.786260  0.793834  0.361370  [[206  51]\n [ 56  87]]
# 28     0.996109   0.654731  0.790123  0.279549  [[256   1]\n [135   8]]
# 59     0.780669   0.774908  0.777778  0.411666  [[210  59]\n [ 61  70]]
# 61     0.802372   0.749077  0.774809  0.350071  [[203  50]\n [ 68  79]]
# 16     0.925926   0.664894  0.773994  0.245787  [[250  20]\n [126   4]]
# 29     0.960784   0.638021  0.766823  0.266591  [[245  10]\n [139   6]]
# 30     0.944882   0.645161  0.766773  0.272282  [[240  14]\n [132  14]]
# 69     0.777778   0.743590  0.760300  0.350344  [[203  58]\n [ 70  69]]
# 60     0.764259   0.752809  0.758491  0.387555  [[201  62]\n [ 66  71]]
# 10     0.932000   0.633152  0.754045  0.250426  [[233  17]\n [135  15]]
# 33     0.901575   0.646893  0.753289  0.294922  [[229  25]\n [125  21]]
# 8      0.932540   0.626667  0.749601  0.255157  [[235  17]\n [140   8]]
# 27     0.955102   0.612565  0.746411  0.292505  [[234  11]\n [148   7]]
# 34     0.873077   0.648571  0.744262  0.274817  [[227  33]\n [123  17]]
# 18     0.962963   0.604651  0.742857  0.282099  [[234   9]\n [153   4]]
# 35     0.890196   0.632312  0.739414  0.283513  [[227  28]\n [132  13]]
# 31     0.790036   0.678899  0.730263  0.301358  [[222  59]\n [105  14]]
# 70     0.760618   0.698582  0.728281  0.341220  [[197  62]\n [ 85  56]]
# 44     0.821561   0.650000  0.725780  0.293681  [[221  48]\n [119  12]]
# 17     0.836576   0.639881  0.725126  0.251335  [[215  42]\n [121  22]]
# 42     0.825926   0.642651  0.722853  0.316604  [[223  47]\n [124   6]]
# 36     0.839080   0.631124  0.720395  0.265699  [[219  42]\n [128  11]]
# 46     0.870079   0.613889  0.719870  0.316401  [[221  33]\n [139   7]]
# 43     0.868000   0.592896  0.704545  0.297515  [[217  33]\n [149   1]]
# 68     0.743083   0.641638  0.688645  0.338417  [[188  65]\n [105  42]]

# %%
ML_compare_variables([SVC(C=1, kernel='rbf'),
                      LinearDiscriminantAnalysis(),
                      neighbors.KNeighborsClassifier(n_neighbors = 3),
                      LogisticRegression(solver= 'liblinear', class_weight = 'balanced')],
                     [["iso_point", "pdel"],
                     ["iso_point", "solv_area"],
                     ["iso_point", "deldel_G1"],
                     ["iso_point", "deldel_G2"],
                     ["iso_point", "deldel_G3"],
                     ["iso_point", "ogAA_letterCode"],
                     ["pdel", "ogAA_letterCode"],
                     ["solv_area", "ogAA_letterCode"],
                     ["deldel_G3", "ogAA_letterCode"],
                     ["deldel_G2", "ogAA_letterCode"],
                     ["deldel_G1", "ogAA_letterCode"],
                     ["pdel", "deldel_G1"],
                     ["pdel", "deldel_G2"],
                     ["pdel", "deldel_G3"],
                     ["pdel", "solv_area"],
                     ["pdel", "iso_point"],
                     ["solv_area", "deldel_G1"],
                     ["solv_area", "deldel_G2"],
                     ["solv_area", "deldel_G3"],
                     ["solv_area", "pdel"],
                     ["solv_area", "iso_point"],                                                   
                     ["iso_point", "pdel", "deldel_G3"],
                     ["iso_point", "pdel", "solv_area"],
                     ["iso_point", "pdel", "ogAA_letterCode"],
                     ["iso_point", "pdel", "deldel_G1"],
                     ["iso_point", "pdel", "deldel_G2"]])
# Out:
#                                                  Model  \
# 52                 KNeighborsClassifier(n_neighbors=3)
# 75                 KNeighborsClassifier(n_neighbors=3)
# 1                                             SVC(C=1)
# 20                                            SVC(C=1)
# 24                                            SVC(C=1)
# 72                 KNeighborsClassifier(n_neighbors=3)
# 67                 KNeighborsClassifier(n_neighbors=3)
# 54                 KNeighborsClassifier(n_neighbors=3)
# 3                                             SVC(C=1)
# 0                                             SVC(C=1)
# 77                 KNeighborsClassifier(n_neighbors=3)
# 22                                            SVC(C=1)
# 74                 KNeighborsClassifier(n_neighbors=3)
# 15                                            SVC(C=1)
# 73                 KNeighborsClassifier(n_neighbors=3)
# 76                 KNeighborsClassifier(n_neighbors=3)
# 56                 KNeighborsClassifier(n_neighbors=3)
# 23                                            SVC(C=1)
# 53                 KNeighborsClassifier(n_neighbors=3)
# 57                 KNeighborsClassifier(n_neighbors=3)
# 2                                             SVC(C=1)
# 55                 KNeighborsClassifier(n_neighbors=3)
# 5                                             SVC(C=1)
# 21                                            SVC(C=1)
# 25                                            SVC(C=1)
# 4                                             SVC(C=1)
# 63                 KNeighborsClassifier(n_neighbors=3)
# 45                        LinearDiscriminantAnalysis()
# 14                                            SVC(C=1)
# 39                        LinearDiscriminantAnalysis()
# 6                                             SVC(C=1)
# 50                        LinearDiscriminantAnalysis()
# 65                 KNeighborsClassifier(n_neighbors=3)
# 12                                            SVC(C=1)
# 40                        LinearDiscriminantAnalysis()
# 11                                            SVC(C=1)
# 38                        LinearDiscriminantAnalysis()
# 19                                            SVC(C=1)
# 58                 KNeighborsClassifier(n_neighbors=3)
# 37                        LinearDiscriminantAnalysis()
# 71                 KNeighborsClassifier(n_neighbors=3)
# 26                        LinearDiscriminantAnalysis()
# 41                        LinearDiscriminantAnalysis()
# 66                 KNeighborsClassifier(n_neighbors=3)
# 13                                            SVC(C=1)
# 32                        LinearDiscriminantAnalysis()
# 47                        LinearDiscriminantAnalysis()
# 64                 KNeighborsClassifier(n_neighbors=3)
# 51                        LinearDiscriminantAnalysis()
# 48                        LinearDiscriminantAnalysis()
# 49                        LinearDiscriminantAnalysis()
# 7                                             SVC(C=1)
# 28                        LinearDiscriminantAnalysis()
# 30                        LinearDiscriminantAnalysis()
# 9                                             SVC(C=1)
# 8                                             SVC(C=1)
# 29                        LinearDiscriminantAnalysis()
# 61                 KNeighborsClassifier(n_neighbors=3)
# 16                                            SVC(C=1)
# 93   LogisticRegression(class_weight='balanced', so...
# 59                 KNeighborsClassifier(n_neighbors=3)
# 99   LogisticRegression(class_weight='balanced', so...
# 101  LogisticRegression(class_weight='balanced', so...
# 62                 KNeighborsClassifier(n_neighbors=3)
# 69                 KNeighborsClassifier(n_neighbors=3)
# 46                        LinearDiscriminantAnalysis()
# 18                                            SVC(C=1)
# 84   LogisticRegression(class_weight='balanced', so...
# 34                        LinearDiscriminantAnalysis()
# 35                        LinearDiscriminantAnalysis()
# 89   LogisticRegression(class_weight='balanced', so...
# 70                 KNeighborsClassifier(n_neighbors=3)
# 27                        LinearDiscriminantAnalysis()
# 44                        LinearDiscriminantAnalysis()
# 10                                            SVC(C=1)
# 91   LogisticRegression(class_weight='balanced', so...
# 60                 KNeighborsClassifier(n_neighbors=3)
# 33                        LinearDiscriminantAnalysis()
# 43                        LinearDiscriminantAnalysis()
# 68                 KNeighborsClassifier(n_neighbors=3)
# 17                                            SVC(C=1)
# 36                        LinearDiscriminantAnalysis()
# 102  LogisticRegression(class_weight='balanced', so...
# 82   LogisticRegression(class_weight='balanced', so...
# 78   LogisticRegression(class_weight='balanced', so...
# 42                        LinearDiscriminantAnalysis()
# 31                        LinearDiscriminantAnalysis()
# 103  LogisticRegression(class_weight='balanced', so...
# 90   LogisticRegression(class_weight='balanced', so...
# 92   LogisticRegression(class_weight='balanced', so...
# 81   LogisticRegression(class_weight='balanced', so...
# 97   LogisticRegression(class_weight='balanced', so...
# 98   LogisticRegression(class_weight='balanced', so...
# 96   LogisticRegression(class_weight='balanced', so...
# 100  LogisticRegression(class_weight='balanced', so...
# 86   LogisticRegression(class_weight='balanced', so...
# 87   LogisticRegression(class_weight='balanced', so...
# 83   LogisticRegression(class_weight='balanced', so...
# 85   LogisticRegression(class_weight='balanced', so...
# 79   LogisticRegression(class_weight='balanced', so...
# 94   LogisticRegression(class_weight='balanced', so...
# 88   LogisticRegression(class_weight='balanced', so...
# 80   LogisticRegression(class_weight='balanced', so...
# 95   LogisticRegression(class_weight='balanced', so...
#
#                                 X Variable(s)  Avg Accuracy  SD of Accuracy  \
# 52                      ['iso_point', 'pdel']        0.9675        0.046837
# 75   ['iso_point', 'pdel', 'ogAA_letterCode']        0.9650        0.052678
# 1                  ['iso_point', 'solv_area']        0.9625        0.073101
# 20                 ['solv_area', 'iso_point']        0.9600        0.058310
# 24         ['iso_point', 'pdel', 'deldel_G1']        0.9550        0.049749
# 72                 ['solv_area', 'iso_point']        0.9525        0.074120
# 67                      ['pdel', 'iso_point']        0.9500        0.074162
# 54                 ['iso_point', 'deldel_G1']        0.9400        0.070000
# 3                  ['iso_point', 'deldel_G2']        0.9400        0.070000
# 0                       ['iso_point', 'pdel']        0.9375        0.069597
# 77         ['iso_point', 'pdel', 'deldel_G2']        0.9350        0.075993
# 22         ['iso_point', 'pdel', 'solv_area']        0.9375        0.069597
# 74         ['iso_point', 'pdel', 'solv_area']        0.9300        0.087178
# 15                      ['pdel', 'iso_point']        0.9350        0.101366
# 73         ['iso_point', 'pdel', 'deldel_G3']        0.9350        0.061441
# 76         ['iso_point', 'pdel', 'deldel_G1']        0.9300        0.060000
# 56                 ['iso_point', 'deldel_G3']        0.9275        0.070666
# 23   ['iso_point', 'pdel', 'ogAA_letterCode']        0.9275        0.074120
# 53                 ['iso_point', 'solv_area']        0.9300        0.095394
# 57           ['iso_point', 'ogAA_letterCode']        0.9300        0.092736
# 2                  ['iso_point', 'deldel_G1']        0.9225        0.065144
# 55                 ['iso_point', 'deldel_G2']        0.9100        0.094340
# 5            ['iso_point', 'ogAA_letterCode']        0.9125        0.095361
# 21         ['iso_point', 'pdel', 'deldel_G3']        0.9150        0.072629
# 25         ['iso_point', 'pdel', 'deldel_G2']        0.9075        0.093240
# 4                  ['iso_point', 'deldel_G3']        0.9050        0.073993
# 63                      ['pdel', 'deldel_G1']        0.8675        0.081815
# 45                      ['solv_area', 'pdel']        0.8675        0.087714
# 14                      ['pdel', 'solv_area']        0.8650        0.096307
# 39                      ['pdel', 'deldel_G3']        0.8625        0.096663
# 6                 ['pdel', 'ogAA_letterCode']        0.8625        0.113330
# 50         ['iso_point', 'pdel', 'deldel_G1']        0.8475        0.124474
# 65                      ['pdel', 'deldel_G3']        0.8575        0.073782
# 12                      ['pdel', 'deldel_G2']        0.8425        0.091890
# 40                      ['pdel', 'solv_area']        0.8575        0.111552
# 11                      ['pdel', 'deldel_G1']        0.8475        0.080584
# 38                      ['pdel', 'deldel_G2']        0.8450        0.113908
# 19                      ['solv_area', 'pdel']        0.8500        0.100000
# 58                ['pdel', 'ogAA_letterCode']        0.8500        0.109545
# 37                      ['pdel', 'deldel_G1']        0.8525        0.102439
# 71                      ['solv_area', 'pdel']        0.8300        0.107703
# 26                      ['iso_point', 'pdel']        0.8125        0.126861
# 41                      ['pdel', 'iso_point']        0.8050        0.134071
# 66                      ['pdel', 'solv_area']        0.8175        0.106975
# 13                      ['pdel', 'deldel_G3']        0.8150        0.082310
# 32                ['pdel', 'ogAA_letterCode']        0.8100        0.109087
# 47         ['iso_point', 'pdel', 'deldel_G3']        0.7850        0.121552
# 64                      ['pdel', 'deldel_G2']        0.8050        0.122372
# 51         ['iso_point', 'pdel', 'deldel_G2']        0.7750        0.106654
# 48         ['iso_point', 'pdel', 'solv_area']        0.7825        0.130168
# 49   ['iso_point', 'pdel', 'ogAA_letterCode']        0.7675        0.133018
# 7            ['solv_area', 'ogAA_letterCode']        0.6975        0.147458
# 28                 ['iso_point', 'deldel_G1']        0.6700        0.134536
# 30                 ['iso_point', 'deldel_G3']        0.6650        0.115217
# 9            ['deldel_G2', 'ogAA_letterCode']        0.6625        0.106507
# 8            ['deldel_G3', 'ogAA_letterCode']        0.6575        0.111552
# 29                 ['iso_point', 'deldel_G2']        0.6450        0.130288
# 61           ['deldel_G2', 'ogAA_letterCode']        0.7050        0.132193
# 16                 ['solv_area', 'deldel_G1']        0.6425        0.122245
# 93                      ['pdel', 'iso_point']        0.7400        0.120000
# 59           ['solv_area', 'ogAA_letterCode']        0.6850        0.144135
# 99         ['iso_point', 'pdel', 'deldel_G3']        0.7175        0.137636
# 101  ['iso_point', 'pdel', 'ogAA_letterCode']        0.7125        0.138180
# 62           ['deldel_G1', 'ogAA_letterCode']        0.6825        0.165662
# 69                 ['solv_area', 'deldel_G2']        0.6700        0.128841
# 46                 ['solv_area', 'iso_point']        0.6100        0.117898
# 18                 ['solv_area', 'deldel_G3']        0.6100        0.160935
# 84                ['pdel', 'ogAA_letterCode']        0.7150        0.131434
# 34           ['deldel_G3', 'ogAA_letterCode']        0.6100        0.141067
# 35           ['deldel_G2', 'ogAA_letterCode']        0.6100        0.130000
# 89                      ['pdel', 'deldel_G1']        0.7100        0.120000
# 70                 ['solv_area', 'deldel_G3']        0.6450        0.130288
# 27                 ['iso_point', 'solv_area']        0.6100        0.130000
# 44                 ['solv_area', 'deldel_G3']        0.6125        0.114428
# 10           ['deldel_G1', 'ogAA_letterCode']        0.6175        0.139441
# 91                      ['pdel', 'deldel_G3']        0.6925        0.100964
# 60           ['deldel_G3', 'ogAA_letterCode']        0.6650        0.135185
# 33           ['solv_area', 'ogAA_letterCode']        0.6050        0.134071
# 43                 ['solv_area', 'deldel_G2']        0.5775        0.129398
# 68                 ['solv_area', 'deldel_G1']        0.6125        0.092702
# 17                 ['solv_area', 'deldel_G2']        0.5900        0.131909
# 36           ['deldel_G1', 'ogAA_letterCode']        0.5650        0.137022
# 102        ['iso_point', 'pdel', 'deldel_G1']        0.6725        0.146607
# 82                 ['iso_point', 'deldel_G3']        0.5875        0.164602
# 78                      ['iso_point', 'pdel']        0.6700        0.140000
# 42                 ['solv_area', 'deldel_G1']        0.5375        0.135439
# 31           ['iso_point', 'ogAA_letterCode']        0.5400        0.144568
# 103        ['iso_point', 'pdel', 'deldel_G2']        0.6475        0.118295
# 90                      ['pdel', 'deldel_G2']        0.6375        0.137273
# 92                      ['pdel', 'solv_area']        0.6450        0.122372
# 81                 ['iso_point', 'deldel_G2']        0.5575        0.190902
# 97                      ['solv_area', 'pdel']        0.6250        0.147902
# 98                 ['solv_area', 'iso_point']        0.5450        0.143091
# 96                 ['solv_area', 'deldel_G3']        0.5375        0.168356
# 100        ['iso_point', 'pdel', 'solv_area']        0.6175        0.135808
# 86           ['deldel_G3', 'ogAA_letterCode']        0.5025        0.125474
# 87           ['deldel_G2', 'ogAA_letterCode']        0.4950        0.124399
# 83           ['iso_point', 'ogAA_letterCode']        0.4850        0.160546
# 85           ['solv_area', 'ogAA_letterCode']        0.4900        0.139284
# 79                 ['iso_point', 'solv_area']        0.5100        0.156205
# 94                 ['solv_area', 'deldel_G1']        0.5175        0.165662
# 88           ['deldel_G1', 'ogAA_letterCode']        0.4575        0.128233
# 80                 ['iso_point', 'deldel_G1']        0.4650        0.232970
# 95                 ['solv_area', 'deldel_G2']        0.4875        0.109972
#
#      Sensitivity  Precision  F1-Score   Runtime         Confusion_Matrix
# 52      1.000000   0.955017  0.976991  0.257559  [[276   0]\n [ 13 111]]
# 75      1.000000   0.948718  0.973684  0.247936  [[259   0]\n [ 14 127]]
# 1       0.984314   0.958015  0.970986  0.192703  [[251   4]\n [ 11 134]]
# 20      1.000000   0.942652  0.970480  0.296027  [[263   0]\n [ 16 121]]
# 24      1.000000   0.935018  0.966418  0.212681  [[259   0]\n [ 18 123]]
# 72      1.000000   0.932624  0.965138  0.234146  [[263   0]\n [ 19 118]]
# 67      1.000000   0.929577  0.963504  0.251490  [[264   0]\n [ 20 116]]
# 54      1.000000   0.915493  0.955882  0.238058  [[260   0]\n [ 24 116]]
# 3       1.000000   0.912727  0.954373  0.193948  [[251   0]\n [ 24 125]]
# 0       1.000000   0.912281  0.954128  0.172169  [[260   0]\n [ 25 115]]
# 77      0.996169   0.912281  0.952381  0.242174  [[260   1]\n [ 25 114]]
# 22      1.000000   0.907749  0.951644  0.247922  [[246   0]\n [ 25 129]]
# 74      1.000000   0.906355  0.950877  0.223251  [[271   0]\n [ 28 101]]
# 15      0.992032   0.912088  0.950382  0.239228  [[249   2]\n [ 24 125]]
# 73      1.000000   0.904762  0.950000  0.230417  [[247   0]\n [ 26 127]]
# 76      1.000000   0.904437  0.949821  0.233898  [[265   0]\n [ 28 107]]
# 56      1.000000   0.901024  0.947935  0.216660  [[264   0]\n [ 29 107]]
# 23      1.000000   0.900344  0.947559  0.236359  [[262   0]\n [ 29 109]]
# 53      1.000000   0.897810  0.946154  0.217096  [[246   0]\n [ 28 126]]
# 57      1.000000   0.896296  0.945312  0.241236  [[242   0]\n [ 28 130]]
# 2       0.984436   0.903571  0.942272  0.173981  [[253   4]\n [ 27 116]]
# 55      1.000000   0.880000  0.936170  0.179184  [[264   0]\n [ 36 100]]
# 5       1.000000   0.875887  0.933837  0.191639  [[247   0]\n [ 35 118]]
# 21      0.967480   0.901515  0.933333  0.262287  [[238   8]\n [ 26 128]]
# 25      0.988417   0.882759  0.932605  0.199230  [[256   3]\n [ 34 107]]
# 4       0.983871   0.877698  0.927757  0.211525  [[244   4]\n [ 34 118]]
# 63      0.929104   0.879859  0.903811  0.231940  [[249  19]\n [ 34  98]]
# 45      0.920455   0.883636  0.901670  0.207373  [[243  21]\n [ 32 104]]
# 14      0.938697   0.865724  0.900735  0.232569  [[245  16]\n [ 38 101]]
# 39      0.892593   0.902622  0.897579  0.209681  [[241  29]\n [ 26 104]]
# 6       0.902344   0.885057  0.893617  0.203493  [[231  25]\n [ 30 114]]
# 50      0.925651   0.858621  0.890877  0.223608  [[249  20]\n [ 41  90]]
# 65      0.887160   0.890625  0.888889  0.241495  [[228  29]\n [ 28 115]]
# 12      0.909420   0.868512  0.888496  0.208308  [[251  25]\n [ 38  86]]
# 40      0.885827   0.889328  0.887574  0.206821  [[225  29]\n [ 28 118]]
# 11      0.923077   0.854093  0.887246  0.222711  [[240  20]\n [ 41  99]]
# 38      0.889706   0.883212  0.886447  0.206971  [[242  30]\n [ 32  96]]
# 19      0.899225   0.872180  0.885496  0.270349  [[232  26]\n [ 34 108]]
# 58      0.900794   0.866412  0.883268  0.230794  [[227  25]\n [ 35 113]]
# 37      0.890688   0.873016  0.881764  0.236479  [[220  27]\n [ 32 121]]
# 71      0.856061   0.882812  0.869231  0.231841  [[226  38]\n [ 30 106]]
# 26      0.913386   0.814035  0.860853  0.232681  [[232  22]\n [ 53  93]]
# 41      0.918919   0.806780  0.859206  0.218185  [[238  21]\n [ 57  84]]
# 66      0.830189   0.887097  0.857700  0.217997  [[220  45]\n [ 28 107]]
# 13      0.879518   0.832700  0.855469  0.245714  [[219  30]\n [ 44 107]]
# 32      0.842742   0.849593  0.846154  0.227665  [[209  39]\n [ 37 115]]
# 47      0.905512   0.787671  0.842491  0.213301  [[230  24]\n [ 62  84]]
# 64      0.854772   0.827309  0.840816  0.232712  [[206  35]\n [ 43 116]]
# 51      0.887640   0.797980  0.840426  0.224457  [[237  30]\n [ 60  73]]
# 48      0.864151   0.817857  0.840367  0.232423  [[229  36]\n [ 51  84]]
# 49      0.830827   0.821561  0.826168  0.217722  [[221  45]\n [ 48  86]]
# 7       0.938406   0.713499  0.810642  0.195680  [[259  17]\n [104  20]]
# 28      0.966418   0.678010  0.796923  0.238955  [[259   9]\n [123   9]]
# 30      0.969925   0.671875  0.793846  0.244901  [[258   8]\n [126   8]]
# 9       0.932331   0.679452  0.786054  0.227802  [[248  18]\n [117  17]]
# 8       0.898551   0.694678  0.783570  0.201171  [[248  28]\n [109  15]]
# 29      0.954717   0.660574  0.780864  0.253287  [[253  12]\n [130   5]]
# 61      0.803846   0.757246  0.779851  0.228030  [[209  51]\n [ 67  73]]
# 16      0.965517   0.652850  0.778980  0.224731  [[252   9]\n [134   5]]
# 93      0.705882   0.861244  0.775862  0.233232  [[180  75]\n [ 29 116]]
# 59      0.799228   0.736655  0.766667  0.249191  [[207  52]\n [ 74  67]]
# 99      0.689394   0.854460  0.763103  0.245093  [[182  82]\n [ 31 105]]
# 101     0.654676   0.905473  0.759916  0.235585  [[182  96]\n [ 19 103]]
# 62      0.746269   0.772201  0.759013  0.245417  [[200  68]\n [ 59  73]]
# 69      0.797665   0.719298  0.756458  0.212720  [[205  52]\n [ 80  63]]
# 46      0.923664   0.640212  0.756250  0.189245  [[242  20]\n [136   2]]
# 18      0.891386   0.652055  0.753165  0.282287  [[238  29]\n [127   6]]
# 84      0.647940   0.896373  0.752174  0.197905  [[173  94]\n [ 20 113]]
# 34      0.848375   0.673352  0.750799  0.233942  [[235  42]\n [114   9]]
# 35      0.896947   0.645604  0.750799  0.221557  [[235  27]\n [129   9]]
# 89      0.652830   0.878173  0.748918  0.276643  [[173  92]\n [ 24 111]]
# 70      0.790262   0.710438  0.748227  0.268739  [[211  56]\n [ 86  47]]
# 27      0.895349   0.641667  0.747573  0.227794  [[231  27]\n [129  13]]
# 44      0.870722   0.654286  0.747145  0.206190  [[229  34]\n [121  16]]
# 10      0.892857   0.641026  0.746269  0.257486  [[225  27]\n [126  22]]
# 91      0.675472   0.828704  0.744283  0.246283  [[179  86]\n [ 37  98]]
# 60      0.812500   0.686620  0.744275  0.244380  [[195  45]\n [ 89  71]]
# 33      0.885827   0.635593  0.740132  0.227706  [[225  29]\n [129  17]]
# 43      0.891473   0.619946  0.731320  0.206521  [[230  28]\n [141   1]]
# 68      0.786260   0.675410  0.726631  0.214074  [[206  56]\n [ 99  39]]
# 17      0.756458   0.676568  0.714286  0.264213  [[205  66]\n [ 98  31]]
# 36      0.832031   0.619186  0.710000  0.244444  [[213  43]\n [131  13]]
# 102     0.606299   0.832432  0.701595  0.216068  [[154 100]\n [ 31 115]]
# 82      0.777328   0.635762  0.699454  0.210021  [[192  55]\n [110  43]]
# 78      0.622951   0.791667  0.697248  0.200047  [[152  92]\n [ 40 116]]
# 42      0.824903   0.602273  0.696223  0.201702  [[212  45]\n [140   3]]
# 31      0.836066   0.586207  0.689189  0.238953  [[204  40]\n [144  12]]
# 103     0.602362   0.792746  0.684564  0.262304  [[153 101]\n [ 40 106]]
# 90      0.559140   0.876404  0.682713  0.214448  [[156 123]\n [ 22  99]]
# 92      0.531496   0.854430  0.655340  0.225007  [[135 119]\n [ 23 123]]
# 81      0.646154   0.664032  0.654971  0.193929  [[168  92]\n [ 85  55]]
# 97      0.507692   0.857143  0.637681  0.233345  [[132 128]\n [ 22 118]]
# 98      0.590038   0.672489  0.628571  0.229004  [[154 107]\n [ 75  64]]
# 96      0.587786   0.666667  0.624746  0.238430  [[154 108]\n [ 77  61]]
# 100     0.510121   0.797468  0.622222  0.224583  [[126 121]\n [ 32 121]]
# 86      0.621622   0.614504  0.618042  0.346458  [[161  98]\n [101  40]]
# 87      0.597744   0.625984  0.611538  0.621621  [[159 107]\n [ 95  39]]
# 83      0.625483   0.597786  0.611321  0.178991  [[162  97]\n [109  32]]
# 85      0.574074   0.635246  0.603113  0.213410  [[155 115]\n [ 89  41]]
# 79      0.563492   0.622807  0.591667  0.184065  [[142 110]\n [ 86  62]]
# 94      0.517110   0.673267  0.584946  0.218167  [[136 127]\n [ 66  71]]
# 88      0.596078   0.571429  0.583493  0.387702  [[152 103]\n [114  31]]
# 80      0.528736   0.602620  0.563265  0.194394  [[138 123]\n [ 91  48]]
# 95      0.473282   0.649215  0.547461  0.208008  [[124 138]\n [ 67  71]]

# %% [markdown]
# ### multi

# %%
ML_compare_variables([SVC(C=1, kernel='rbf'),LinearDiscriminantAnalysis(), neighbors.KNeighborsClassifier(n_neighbors = 3)],[["iso_point", "pdel","ogAA_letterCode"]])
