# %%
import pandas as pd
import numpy as np
import timeit #imports timeit module
from sklearn import preprocessing
from sklearn.model_selection import KFold, LeaveOneOut,cross_val_score, train_test_split
from sklearn.metrics import confusion_matrix, classification_report,f1_score,accuracy_score,precision_score,recall_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import neighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

def standardize(x): 
    
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x)
    df1 = pd.DataFrame(x_scaled)
    return(df1)

def ML_summary(Vars, model = None):
    
    #define X and y variables
    X = df.loc[:, Vars] 
    y = df.loc[:, "positive_negative"] 

    #standardize data
    X = standardize(X)

    #set the model
    if model == None:
        raise Exception("Needs Model")

    #set the CV
    kf = LeaveOneOut()
    
    #start timer for getting elapsed time
    from time import time
    import timeit #imports timeit module
    start_time = timeit.default_timer() #defines start time so computational time can be calculated

    #define lists
    acc_score = [];
    Truth = [];
    Output = [];

    #loop though each fold (so 40 times in our case)
    for train_index , test_index in kf.split(df):
        
        #split the data
        X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = .25, shuffle=True)

        #print(X_train); print(X_test); print(y_train); print(y_test)
        
        #fit the model
        model.fit(X_train,y_train)
        
        #preduct values
        pred_values = model.predict(X_test)

        #append the accuracy score
        acc = accuracy_score(pred_values, y_test)
        acc_score.append(acc)

        #add to the truth and output
        Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
        Output.extend(pred_values); ## it is a list  
        

 
    #determine the time elapesed
    elapsed = timeit.default_timer() - start_time #gives total computation time

    #return the dataframe
    #test = pd.DataFrame(data={"Predicted:": Output, "Real": Truth})
    
    #set output to a dataframe
    dfOutput = pd.DataFrame(data={"Model": str(model),
                                  "X Variable(s)": [str(Vars),],
                                  "Avg Accuracy": [np.mean(acc_score),],
                                  "SD of Accuracy": [np.std(acc_score),],
                                  "Sensitivity": [recall_score(Truth,Output,pos_label="negative"),],
                                  "Precision": [precision_score(Truth,Output,pos_label="negative"),],
                                  "F1-Score": [f1_score(Truth,Output,pos_label="negative"),],
                                  "Runtime": [elapsed,],
                                  "Confusion_Matrix": str(confusion_matrix(Truth,Output))}) #,"Real Specificity": [1,]
    #return output
    #test = pd.DataFrame(data={"Predicted:": Output, "Real": Truth})
    
    return dfOutput


def ML_compare_variables(modelList,variableList):
    
    outputList = []
    
    for j in modelList:
        
        outputList1 = []
        
        for i in variableList :
            outputList1.append(ML_summary(i,j))
            
        outputList1 = pd.concat(outputList1, ignore_index = True)
        
        outputList.append(outputList1)
    
    outputList = pd.concat(outputList, ignore_index = True)
    
    
    return outputList.sort_values(by = "F1-Score",ascending=False)

# %%
df = pd.read_csv('data/Cataract Data 1.3.csv', na_values='?').dropna()
pd.set_option('display.max_rows', None)

# %%
#summery of all vars
ML_summary(["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"],RandomForestClassifier(max_depth=3))

#Compare all variables
ML_compare_variables([LogisticRegression(solver= 'liblinear', class_weight = 'balanced'),
                      neighbors.KNeighborsClassifier(n_neighbors = 3),
                      LinearDiscriminantAnalysis(),
                      DecisionTreeClassifier(max_depth=3),
                      BaggingClassifier(),
                      RandomForestClassifier(max_depth = 3),
                      AdaBoostClassifier(n_estimators=500, learning_rate = 0.1, algorithm="SAMME.R"),
                      GradientBoostingClassifier(n_estimators = 500, learning_rate = 0.1, max_depth = 4),
                      SVC(C=1, kernel='linear')],
                           [["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"]])

# %% [markdown]
# # Logistic Regression:

# %%
ML_compare_variables([LogisticRegression(solver= 'liblinear', class_weight = 'balanced')],
                     [["iso_point"],
                      ["pdel"],
                      ["iso_point","pdel"],
                      ["solv_area"],
                      ["iso_point","solv_area"],
                      ["iso_point","pdel","deldel_G3"]])
# Out:
#                                                Model  \
# 5  LogisticRegression(class_weight='balanced', so...
# 2  LogisticRegression(class_weight='balanced', so...
# 1  LogisticRegression(class_weight='balanced', so...
# 0  LogisticRegression(class_weight='balanced', so...
# 3  LogisticRegression(class_weight='balanced', so...
# 4  LogisticRegression(class_weight='balanced', so...
#
#                         X Variable(s)  Avg Accuracy  SD of Accuracy  \
# 5  ['iso_point', 'pdel', 'deldel_G3']        0.7075        0.117020
# 2               ['iso_point', 'pdel']        0.6925        0.147288
# 1                            ['pdel']        0.6575        0.197342
# 0                       ['iso_point']        0.5325        0.362896
# 3                       ['solv_area']        0.4925        0.147288
# 4          ['iso_point', 'solv_area']        0.4725        0.151637
#
#    Sensitivity  Precision  F1-Score   Runtime         Confusion_Matrix
# 5     0.690037   0.850000  0.761711  0.124207  [[187  84]\n [ 33  96]]
# 2     0.619048   0.852459  0.717241  0.122653  [[156  96]\n [ 27 121]]
# 1     0.539623   0.905063  0.676123  0.122810  [[143 122]\n [ 15 120]]
# 0     0.625468   0.657480  0.641075  0.127373  [[167 100]\n [ 87  46]]
# 3     0.466667   0.681081  0.553846  0.123021  [[126 144]\n [ 59  71]]
# 4     0.520000   0.588235  0.552017  0.124636  [[130 120]\n [ 91  59]]

# %% [markdown]
# # KNN:

# %%
def KNN_find_best_k(inputList,_max):
    
    outputList = [pd.DataFrame(data={"X Variable(s)": [inputList,],
                                      "Avg Accuracy": 0.0,
                                      "SD of Accuracy": 0.0,
                                      "Sensitivity": 0.0,
                                      "Precision": 0.0,
                                      "F1-Score": 0.0,
                                      "Runtime": 0.0,
                                      "Confusion_Matrix": "none"})] #,"Real Specificity": [1,]
    
    for i in range(1,_max):
        
        tempList = []
        
        for j in range(10):
            tempList.append(ML_summary(inputList,neighbors.KNeighborsClassifier(n_neighbors = i)))
            
        tempList = pd.concat(tempList, ignore_index=True)

        outputList.append(tempList.head(1))

    outputList = pd.concat(outputList, ignore_index=True)
    
    return outputList.sort_values(by = "F1-Score",ascending=False)

KNN_find_best_k(["iso_point","pdel"],5)
# Out:
#            X Variable(s)  Avg Accuracy  SD of Accuracy  Sensitivity  \
# 3  ['iso_point', 'pdel']        0.9475        0.063196      1.00000
# 4  ['iso_point', 'pdel']        0.9450        0.094736      1.00000
# 2  ['iso_point', 'pdel']        0.9350        0.085294      1.00000
# 1  ['iso_point', 'pdel']        0.8750        0.123996      0.88764
# 0      [iso_point, pdel]        0.0000        0.000000      0.00000
#
#    Precision  F1-Score   Runtime         Confusion_Matrix  \
# 3   0.926829  0.962025  0.158845  [[266   0]\n [ 21 113]]
# 4   0.923077  0.960000  0.164392  [[264   0]\n [ 22 114]]
# 2   0.905797  0.950570  0.160325  [[250   0]\n [ 26 124]]
# 1   0.922179  0.904580  0.166354  [[237  30]\n [ 20 113]]
# 0   0.000000  0.000000  0.000000                     none
#
#                                  Model
# 3  KNeighborsClassifier(n_neighbors=3)
# 4  KNeighborsClassifier(n_neighbors=4)
# 2  KNeighborsClassifier(n_neighbors=2)
# 1  KNeighborsClassifier(n_neighbors=1)
# 0                                  NaN

# %%
ML_compare_variables([neighbors.KNeighborsClassifier(n_neighbors = 3)],[[],[],[],[],[]])

# %% [markdown]
# # LDA:

# %%
ML_compare_variables([LinearDiscriminantAnalysis()],
                     [["iso_point","pdel"],
                      ["iso_point"],
                      ["pdel"]])
# Out:
#                           Model          X Variable(s)  Avg Accuracy  \
# 2  LinearDiscriminantAnalysis()               ['pdel']        0.8950
# 0  LinearDiscriminantAnalysis()  ['iso_point', 'pdel']        0.8225
# 1  LinearDiscriminantAnalysis()          ['iso_point']        0.6250
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 2        0.083516     0.938224   0.903346  0.920455  0.132942
# 0        0.119347     0.916000   0.820789  0.865784  0.141594
# 1        0.119896     1.000000   0.617347  0.763407  0.132677
#
#           Confusion_Matrix
# 2  [[243  16]\n [ 26 115]]
# 0  [[229  21]\n [ 50 100]]
# 1  [[242   0]\n [150   8]]

# %% [markdown]
# # Basic Decision Tree:
#
# 6 is best max_depth

# %%
def basticDT_find_best_k(inputList,_max):
    
    outputList = [pd.DataFrame(data={"X Variable(s)": [inputList,],
                                      "Avg Accuracy": 0.0,
                                      "SD of Accuracy": 0.0,
                                      "Sensitivity": 0.0,
                                      "Precision": 0.0,
                                      "F1-Score": 0.0,
                                      "Runtime": 0.0,
                                      "Confusion_Matrix": "none"})] #,"Real Specificity": [1,]
    
    for i in range(1,_max):
        
        tempList = []
        
        for j in range(20):
            tempList.append(ML_summary(inputList,DecisionTreeClassifier(max_depth=i)))
            
        tempList = pd.concat(tempList, ignore_index=True)

        outputList.append(tempList.head(1))

    outputList = pd.concat(outputList, ignore_index=True)
    
    return outputList.sort_values(by = "F1-Score",ascending=False)

basticDT_find_best_k(["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"],10)
# Out:
#                                        X Variable(s)  Avg Accuracy  \
# 2  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8700
# 6  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8775
# 7  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8600
# 8  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8575
# 4  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8650
# 5  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8550
# 3  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8550
# 9  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8400
# 1  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.7625
# 0  [pdel, iso_point, deldel_G1, deldel_G2, deldel...        0.0000
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 2        0.112250     0.914498   0.894545  0.904412  0.124251
# 6        0.101211     0.901575   0.905138  0.903353  0.124536
# 7        0.101980     0.903346   0.890110  0.896679  0.119770
# 8        0.099718     0.906015   0.882784  0.894249  0.122381
# 4        0.115217     0.890196   0.897233  0.893701  0.120866
# 5        0.126392     0.896552   0.883019  0.889734  0.119316
# 3        0.113908     0.887597   0.887597  0.887597  0.123866
# 9        0.091652     0.861660   0.882591  0.872000  0.120278
# 1        0.101704     0.836735   0.788462  0.811881  0.127687
# 0        0.000000     0.000000   0.000000  0.000000  0.000000
#
#           Confusion_Matrix                                Model
# 2  [[246  23]\n [ 29 102]]  DecisionTreeClassifier(max_depth=2)
# 6  [[229  25]\n [ 24 122]]  DecisionTreeClassifier(max_depth=6)
# 7  [[243  26]\n [ 30 101]]  DecisionTreeClassifier(max_depth=7)
# 8  [[241  25]\n [ 32 102]]  DecisionTreeClassifier(max_depth=8)
# 4  [[227  28]\n [ 26 119]]  DecisionTreeClassifier(max_depth=4)
# 5  [[234  27]\n [ 31 108]]  DecisionTreeClassifier(max_depth=5)
# 3  [[229  29]\n [ 29 113]]  DecisionTreeClassifier(max_depth=3)
# 9  [[218  35]\n [ 29 118]]  DecisionTreeClassifier(max_depth=9)
# 1  [[205  40]\n [ 55 100]]  DecisionTreeClassifier(max_depth=1)
# 0                     none                                  NaN

# %%
ML_summary(["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"],DecisionTreeClassifier(max_depth=6))
# Out:
#                                  Model  \
# 0  DecisionTreeClassifier(max_depth=6)
#
#                                        X Variable(s)  Avg Accuracy  \
# 0  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...         0.865
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 0        0.090967      0.88764   0.908046  0.897727  0.126963
#
#           Confusion_Matrix
# 0  [[237  30]\n [ 24 109]]

# %% [markdown]
# # Bagging Decision Tree:

# %%
ML_summary(["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"],BaggingClassifier())
# Out:
#                  Model                                      X Variable(s)  \
# 0  BaggingClassifier()  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...
#
#    Avg Accuracy  SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 0        0.8775         0.09871     0.921642   0.898182  0.909761  0.686576
#
#           Confusion_Matrix
# 0  [[247  21]\n [ 28 104]]

# %% [markdown]
# # Random Forest:
# Best max_depth = 2

# %%
ML_compare_variables(
[RandomForestClassifier(max_depth=1),
RandomForestClassifier(max_depth=2),
RandomForestClassifier(max_depth=3),
RandomForestClassifier(max_depth=4),
RandomForestClassifier(max_depth=5),
RandomForestClassifier(max_depth=6),
RandomForestClassifier(max_depth=7),
RandomForestClassifier(max_depth=8),
RandomForestClassifier(max_depth=9),
RandomForestClassifier(max_depth=None)],[["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"]])
# Out:
#                                  Model  \
# 1  RandomForestClassifier(max_depth=2)
# 8  RandomForestClassifier(max_depth=9)
# 3  RandomForestClassifier(max_depth=4)
# 6  RandomForestClassifier(max_depth=7)
# 5  RandomForestClassifier(max_depth=6)
# 9             RandomForestClassifier()
# 2  RandomForestClassifier(max_depth=3)
# 7  RandomForestClassifier(max_depth=8)
# 4  RandomForestClassifier(max_depth=5)
# 0  RandomForestClassifier(max_depth=1)
#
#                                        X Variable(s)  Avg Accuracy  \
# 1  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.9050
# 8  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.9025
# 3  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.9025
# 6  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8925
# 5  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8900
# 9  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8925
# 2  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8925
# 7  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8925
# 4  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8900
# 0  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.8425
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 1        0.066895     0.966790   0.900344  0.932384  4.669706
# 8        0.079017     0.947566   0.910072  0.928440  4.677599
# 3        0.087999     0.938931   0.914498  0.926554  4.614884
# 6        0.081815     0.966418   0.883959  0.923351  4.721092
# 5        0.086023     0.977695   0.873754  0.922807  4.705219
# 9        0.087714     0.951128   0.893993  0.921676  4.749211
# 2        0.087714     0.961686   0.883803  0.921101  4.714462
# 7        0.095884     0.961390   0.882979  0.920518  4.690920
# 4        0.083066     0.988235   0.860068  0.919708  4.673355
# 0        0.149812     0.996047   0.802548  0.888889  4.638323
#
#           Confusion_Matrix
# 1  [[262   9]\n [ 29 100]]
# 8  [[253  14]\n [ 25 108]]
# 3  [[246  16]\n [ 23 115]]
# 6  [[259   9]\n [ 34  98]]
# 5  [[263   6]\n [ 38  93]]
# 9  [[253  13]\n [ 30 104]]
# 2  [[251  10]\n [ 33 106]]
# 7  [[249  10]\n [ 33 108]]
# 4  [[252   3]\n [ 41 104]]
# 0  [[252   1]\n [ 62  85]]

# %%
ML_summary(["pdel","iso_point","deldel_G1","deldel_G2","deldel_G3","positionAA_num","solv_area","evo_age"],RandomForestClassifier(max_depth=2))
# Out:
#                                  Model  \
# 0  RandomForestClassifier(max_depth=2)
#
#                                        X Variable(s)  Avg Accuracy  \
# 0  ['pdel', 'iso_point', 'deldel_G1', 'deldel_G2'...        0.9175
#
#    SD of Accuracy  Sensitivity  Precision  F1-Score   Runtime  \
# 0        0.070312      0.97786   0.907534  0.941385  4.705576
#
#           Confusion_Matrix
# 0  [[265   6]\n [ 27 102]]

# %% [markdown]
# # Ada Boosting Decision Tree:

# %%
ML_compare_variables([AdaBoostClassifier(n_estimators=5000, learning_rate = 0.05)],[["pdel","iso_point"]])

# %% [markdown]
# # Gradient Boosting Decision Tree:

# %%
GradientBoostingClassifier(n_estimators = 500, learning_rate = 0.1, max_depth = 4)

# %% [markdown]
# # Support Vector Classifier:
# Best kernal = "rbf" (default)

# %%
ML_compare_variables([SVC(C=1, kernel='linear'),SVC(C=1, kernel='poly'),SVC(C=1, kernel='rbf'),SVC(C=1, kernel='sigmoid')],[["iso_point","pdel"]])

# %%
def SVC_find_best_c(inputList,_max):
    
    outputList = [pd.DataFrame(data={"X Variable(s)": [inputList,],
                                      "Avg Accuracy": 0.0,
                                      "SD of Accuracy": 0.0,
                                      "Sensitivity": 0.0,
                                      "Precision": 0.0,
                                      "F1-Score": 0.0,
                                      "Runtime": 0.0,
                                      "Confusion_Matrix": "none"})] #,"Real Specificity": [1,]
    
    for i in range(1,_max):
        
        tempList = []
        
        for j in range(10):
            tempList.append(ML_summary(inputList,SVC(C=i, kernel='rbf')))
            
        tempList = pd.concat(tempList, ignore_index=True)

        outputList.append(tempList.head(1))

    outputList = pd.concat(outputList, ignore_index=True)
    
    return outputList.sort_values(by = "F1-Score",ascending=False)

SVC_find_best_c(["iso_point","pdel"],10)
# Out:
#            X Variable(s)  Avg Accuracy  SD of Accuracy  Sensitivity  \
# 7  ['iso_point', 'pdel']        0.9625        0.061998     0.992620
# 6  ['iso_point', 'pdel']        0.9525        0.063196     0.992218
# 2  ['iso_point', 'pdel']        0.9500        0.070711     0.984791
# 9  ['iso_point', 'pdel']        0.9450        0.063048     1.000000
# 4  ['iso_point', 'pdel']        0.9450        0.092060     0.992366
# 8  ['iso_point', 'pdel']        0.9425        0.091890     0.992188
# 3  ['iso_point', 'pdel']        0.9400        0.066332     1.000000
# 1  ['iso_point', 'pdel']        0.9275        0.089408     0.992395
# 5  ['iso_point', 'pdel']        0.9275        0.077419     0.977011
# 0      [iso_point, pdel]        0.0000        0.000000     0.000000
#
#    Precision  F1-Score   Runtime         Confusion_Matrix     Model
# 7   0.953901  0.972875  0.124815  [[269   2]\n [ 13 116]]  SVC(C=7)
# 6   0.937500  0.964083  0.128732  [[255   2]\n [ 17 126]]  SVC(C=6)
# 2   0.941818  0.962825  0.128206  [[259   4]\n [ 16 121]]  SVC(C=2)
# 9   0.925926  0.961538  0.127473  [[275   0]\n [ 22 103]]  SVC(C=9)
# 4   0.928571  0.959410  0.126926  [[260   2]\n [ 20 118]]  SVC(C=4)
# 8   0.923636  0.956685  0.126808  [[254   2]\n [ 21 123]]  SVC(C=8)
# 3   0.915789  0.956044  0.124866  [[261   0]\n [ 24 115]]  SVC(C=3)
# 1   0.906250  0.947368  0.130629  [[261   2]\n [ 27 110]]  SVC(C=1)
# 5   0.917266  0.946197  0.126839  [[255   6]\n [ 23 116]]  SVC(C=5)
# 0   0.000000  0.000000  0.000000                     none       NaN
